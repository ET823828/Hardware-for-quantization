# %% [markdown]
# # Project 4 — Milestone 1: Quantization Workload Augmentation
#
# This notebook follows the AccelForge workflow from the lab:
# 1. define workload YAML (`iteration_space_shape`, `bits_per_value`, `einsums`)
# 2. load with `af.Spec.from_yaml(...)`
# 3. run `spec.evaluate_mapping()`
# 4. compare baseline vs quantized workload

# %% [markdown]
# ## Milestone 1 tasks (from project_4.pdf)
#
# - Study hardware cost of supporting quantization
# - Create a compound component to model quantization area/energy
# - Pick a workload and augment the spec with einsums that represent quantization
#
# This notebook focuses on the third bullet using a minimal weight-only NVFP4-style model.

# %%
from pathlib import Path
import os
import yaml

try:
    import accelforge as af
    AF_AVAILABLE = True
except Exception as e:
    af = None
    AF_AVAILABLE = False
    print("accelforge import failed:", e)
    print("Notebook will still generate workload/mapping YAML files.")
    print("Run evaluation cells in your AccelForge-enabled environment.")


def find_lab_root() -> Path:
    cwd = Path.cwd()

    # Optional explicit override
    env_root = os.environ.get("AF_LAB4_ROOT")
    if env_root:
        return Path(env_root).expanduser()

    # If launched from lab_4 directly
    if (cwd / "project4_m1_quantization_workload.ipynb").exists() or (cwd / "project4_m1").exists():
        return cwd

    # Common nested layout: <repo>/workspace/lab_4
    nested = cwd / "workspace" / "lab_4"
    if nested.exists():
        return nested

    # Known local absolute path fallbacks
    known_paths = [
        Path("/Users/yichongzhang/Desktop/\u5927\u5b66/\u5927\u4e09\u4e0b/hardware design for AI accelerators/final project/Hardware-for-quantization/workspace/lab_4"),
        Path("/Users/bearxiong/Documents/MIT/Deep_Learning/Final-Project/workspace/lab_4"),
    ]
    for known in known_paths:
        if known.exists():
            return known

    return cwd


ROOT = find_lab_root()
OUT_DIR = ROOT / "project4_m1"
OUT_DIR.mkdir(exist_ok=True)

# Standalone architecture file (no part6 dependency)
ARCH_FILE = OUT_DIR / "arch_template.yaml"
# ========== Architecture Parameters (adjust these!) ==========
ARCH_PARAMS = dict(
    GLB_SIZE = 524288,    # GLB capacity in bits (524288 = 64KB)
    RF_SIZE  = 1024,      # RF capacity per PE in bits (1024 = 128B)
    PE_X     = 8,         # spatial X fanout (PE array width)
    PE_Y     = 8,         # spatial Y fanout (PE array height)
    DRAM_BW  = 8,         # DRAM actions/cycle
    GLB_BW   = 32,        # GLB actions/cycle
)
# Total PEs = PE_X * PE_Y
print(f"Architecture: GLB={ARCH_PARAMS['GLB_SIZE']//8//1024}KB, "
      f"RF={ARCH_PARAMS['RF_SIZE']//8}B/PE, "
      f"PEs={ARCH_PARAMS['PE_X']}x{ARCH_PARAMS['PE_Y']}="
      f"{ARCH_PARAMS['PE_X']*ARCH_PARAMS['PE_Y']}")


def dump_yaml(path: Path, obj: dict):
    with open(path, "w") as f:
        yaml.safe_dump(obj, f, sort_keys=False)


def evaluate(arch_file: Path, workload_file: Path, mapping_file: Path, jinja_data=None):
    if not AF_AVAILABLE:
        raise RuntimeError("accelforge is unavailable in this kernel.")
    for fp in [arch_file, workload_file, mapping_file]:
        if not Path(fp).exists():
            raise FileNotFoundError(f"Missing required file: {fp}")
    spec = af.Spec.from_yaml(str(arch_file), str(workload_file), str(mapping_file), jinja_parse_data=jinja_data)
    result = spec.evaluate_mapping()
    return result


print("Working directory:", Path.cwd())
print("Lab root:", ROOT)
print("Output directory:", OUT_DIR)
print("Architecture:", ARCH_FILE)
# Out:
# Architecture: GLB=64KB, RF=128B/PE, PEs=8x8=64
# Working directory: /home/workspace/workspace/lab_4
# Lab root: /home/workspace/workspace/lab_4
# Output directory: /home/workspace/workspace/lab_4/project4_m1
# Architecture: /home/workspace/workspace/lab_4/project4_m1/arch_template.yaml

# %% [markdown]
# ## Step 1: Baseline dense GEMM workload
#
# Start from a simple lab-style workload with one einsum.

# %%
baseline_workload = {
    "workload": {
        "iteration_space_shape": {
            "m": "0 <= m < 64",
            "n": "0 <= n < 64",
            "k": "0 <= k < 128",
        },
        "bits_per_value": {
            "A": 16,
            "W": 16,
            "Y": 16,
        },
        "einsums": [
            {
                "name": "MatMul",
                "tensor_accesses": [
                    {"name": "A", "projection": ["m", "k"], "density": 1.0},
                    {"name": "W", "projection": ["n", "k"], "density": 1.0},
                    {"name": "Y", "projection": ["m", "n"], "output": True},
                ],
            }
        ],
    }
}

baseline_workload_file = OUT_DIR / "workload_baseline.yaml"
baseline_mapping_file = OUT_DIR / "mapping_baseline.yaml"

baseline_mapping_text = """
mapping:
  nodes:
  - !Storage
    tensors: [A, W, Y]
    component: DRAM
  - !Temporal
    rank_variable: m
    tile_shape: 8
  - !Temporal
    rank_variable: n
    tile_shape: 8
  - !Temporal
    rank_variable: k
    tile_shape: 8
  - !Storage
    tensors: [A, W, Y]
    component: GLB
  - !Temporal
    rank_variable: n
    tile_shape: 1
  - !Temporal
    rank_variable: k
    tile_shape: 1
  - !Temporal
    rank_variable: m
    tile_shape: 1
  - !Spatial
    rank_variable: m
    tile_shape: 1
    name: X
    component: RF
  - !Compute
    einsum: MatMul
    component: FP16MAC
""".strip()

dump_yaml(baseline_workload_file, baseline_workload)
baseline_mapping_file.write_text(baseline_mapping_text)

print("Wrote baseline workload:", baseline_workload_file)
print("Wrote baseline mapping:", baseline_mapping_file)
# Out:
# Wrote baseline workload: /home/workspace/workspace/lab_4/project4_m1/workload_baseline.yaml
# Wrote baseline mapping: /home/workspace/workspace/lab_4/project4_m1/mapping_baseline.yaml

# %%
if AF_AVAILABLE and ARCH_FILE.exists() and baseline_mapping_file.exists():
    baseline_result = evaluate(ARCH_FILE, baseline_workload_file, baseline_mapping_file, ARCH_PARAMS)
    print("Baseline mapping evaluation completed.")
    print(baseline_result)
else:
    print("Skipped baseline evaluate_mapping().")
    print("AF_AVAILABLE:", AF_AVAILABLE)
    print("arch exists:", ARCH_FILE.exists(), ARCH_FILE)
    print("mapping exists:", baseline_mapping_file.exists(), baseline_mapping_file)
# Out:
# Baseline mapping evaluation completed.
# <accelforge.mapper.FFM.mappings.Mappings object at 0x7150b5993e00>

# %% [markdown]
# ## Step 2–6: NVFP4-style weight-only augmentation
#
# We now augment the workload spec with explicit quantization tensors and einsums:
# - split `k -> kb, ki` with `ki=16`
# - add quantized weights `Wq[n,kb,ki]`
# - add block scales `Sw[n,kb]`
# - add dequantized weights `Wdq[n,kb,ki]`
# - add `DequantW` einsum before the main GEMM
# - update GEMM to consume `Wdq`

# %%
quant_workload = {
    "workload": {
        "iteration_space_shape": {
            "m": "0 <= m < 64",
            "n": "0 <= n < 64",
            "kb": "0 <= kb < 8",
            "ki": "0 <= ki < 16",
        },
        "bits_per_value": {
            "A": 16,
            "Wq": 4,
            "Sw": 16,
            "Wdq": 16,
            "Y": 16,
        },
        "einsums": [
            {
                "name": "DequantW",
                "tensor_accesses": [
                    {"name": "Wq", "projection": ["n", "kb", "ki"], "density": 1.0},
                    {"name": "Sw", "projection": ["n", "kb"], "density": 1.0},
                    {"name": "Wdq", "projection": ["n", "kb", "ki"], "output": True},
                ],
            },
            {
                "name": "MatMulQ",
                "tensor_accesses": [
                    {"name": "A", "projection": ["m", "kb", "ki"], "density": 1.0},
                    {"name": "Wdq", "projection": ["n", "kb", "ki"], "density": 1.0},
                    {"name": "Y", "projection": ["m", "n"], "output": True},
                ],
            },
        ],
    }
}

quant_workload_file = OUT_DIR / "workload_nvfp4_weight_only.yaml"
dump_yaml(quant_workload_file, quant_workload)
print("Wrote quantized workload:", quant_workload_file)
with open(quant_workload_file) as f:
    print(f.read())
# Out:
# Wrote quantized workload: /home/workspace/workspace/lab_4/project4_m1/workload_nvfp4_weight_only.yaml
# workload:
#   iteration_space_shape:
#     m: 0 <= m < 64
#     n: 0 <= n < 64
#     kb: 0 <= kb < 8
#     ki: 0 <= ki < 16
#   bits_per_value:
#     A: 16
#     Wq: 4
#     Sw: 16
#     Wdq: 16
#     Y: 16
#   einsums:
#   - name: DequantW
#     tensor_accesses:
#     - name: Wq
#       projection:
#       - n
#       - kb
#       - ki
#       density: 1.0
#     - name: Sw
#       projection:
#       - n
#       - kb
#       density: 1.0
#     - name: Wdq
#       projection:
#       - n
#       - kb
#       - ki
#       output: true
#   - name: MatMulQ
#     tensor_accesses:
#     - name: A
#       projection:
#       - m
#       - kb
#       - ki
#       density: 1.0
#     - name: Wdq
#       projection:
#       - n
#       - kb
#       - ki
#       density: 1.0
#     - name: Y
#       projection:
#       - m
#       - n
#       output: true

# %% [markdown]
# ## Step 8: Validate with AccelForge (`from_yaml` + `evaluate_mapping()`)
#
# We generate a first-pass quantized mapping that includes both einsums:
# - `DequantW`
# - `MatMulQ`
#
# If mapping evaluation fails due scheduler constraints, the parser check still confirms workload structure validity and you can iterate the mapping next.

# %%
quant_mapping_file = OUT_DIR / "mapping_nvfp4_weight_only.yaml"
quant_mapping_text = """
mapping:
  nodes:
  - !Storage
    tensors: [A, Wq, Sw, Wdq, Y]
    component: DRAM
  - !Temporal
    rank_variable: m
    tile_shape: 8
  - !Temporal
    rank_variable: n
    tile_shape: 4
  - !Temporal
    rank_variable: kb
    tile_shape: 2
  - !Temporal
    rank_variable: ki
    tile_shape: 8
  - !Storage
    tensors: [A, Wq, Sw, Wdq, Y]
    component: GLB
  - !Temporal
    rank_variable: n
    tile_shape: 1
  - !Temporal
    rank_variable: kb
    tile_shape: 1
  - !Temporal
    rank_variable: ki
    tile_shape: 1
  - !Temporal
    rank_variable: m
    tile_shape: 1
  - !Spatial
    rank_variable: m
    tile_shape: 1
    name: X
    component: RF
  - !Compute
    einsum: DequantW
    component: QuantMAC
  - !Compute
    einsum: MatMulQ
    component: FP16MAC
""".strip()

quant_mapping_file.write_text(quant_mapping_text)
print("Wrote quantized mapping:", quant_mapping_file)

if AF_AVAILABLE and ARCH_FILE.exists() and quant_workload_file.exists() and quant_mapping_file.exists():
    # Parser validation + mapping evaluation
    spec_q = af.Spec.from_yaml(str(ARCH_FILE), str(quant_workload_file), str(quant_mapping_file), jinja_parse_data=ARCH_PARAMS)
    print("Quantized spec parsed successfully.")

    try:
        quant_result = spec_q.evaluate_mapping()
        print("Quantized mapping evaluation completed.")
        print(quant_result)
    except Exception as e:
        print("Quantized mapping parse succeeded, but evaluate_mapping() needs mapping refinement:")
        print(type(e).__name__, e)
else:
    print("Skipped Spec.from_yaml/evaluate_mapping().")
    print("AF_AVAILABLE:", AF_AVAILABLE)
    print("arch exists:", ARCH_FILE.exists(), ARCH_FILE)
    print("workload exists:", quant_workload_file.exists(), quant_workload_file)
    print("mapping exists:", quant_mapping_file.exists(), quant_mapping_file)
# Out:
# Wrote quantized mapping: /home/workspace/workspace/lab_4/project4_m1/mapping_nvfp4_weight_only.yaml
# Quantized spec parsed successfully.
# Quantized mapping parse succeeded, but evaluate_mapping() needs mapping refinement:
# ValueError Component QuantMAC not found in flattened arch

# %% [markdown]
# ## Full NVFP4 Quantization (W4A4) — Two-Level Scaling
#
# NVIDIA's NVFP4 on Blackwell uses **two-level scaling**:
# - **Per-tensor scale** (coarse): One FP32 scalar per entire tensor. `projection: []`.
# - **Per-block scale** (fine): One FP8 (E4M3) scale per block of 16 elements along K.
#
# ### Quantization (FP16 → FP4):
# 1. `TensorScaleA`: $S_{ga} = \text{reduce}_{m,k_b,k_i}(|A|)$ — per-tensor scale (scalar)
# 2. `TensorQuantA`: $A_{scl} = A \times S_{ga}^{-1}$
# 3. `BlockScaleA`: $S_{ba}[m,k_b] = \text{reduce}_{k_i}(|A_{scl}|)$ — per-block scale
# 4. `BlockQuantA`: $A_q = A_{scl} \times S_{ba}^{-1}$ — quantize to FP4
# 5–8. Same for weights
#
# ### FP4 × FP4 Compute (FP32 accumulate):
# 9. `MatMulNVFP4`: $Y_{raw}[m,n,k_b] \mathrel{+}= A_q \times W_q$ — reduce $k_i$
#
# ### Rescale (2 inputs per einsum):
# 10. `RescaleBlockA`: $Y_{tmp} = Y_{raw} \times S_{ba}[m,k_b]$
# 11. `RescaleBlockW`: $Y_{blk} = Y_{tmp} \times S_{bw}[n,k_b]$
# 12. `RescaleTensorA`: $Y_{tmp2}[m,n] = \sum_{k_b} Y_{blk} \times S_{ga}$ — reduce $k_b$
# 13. `RescaleTensorW`: $Y = Y_{tmp2} \times S_{gw}$

# %%
nvfp4_full_workload = {
    "workload": {
        "iteration_space_shape": {
            "m": "0 <= m < 64",
            "n": "0 <= n < 64",
            "kb": "0 <= kb < 8",
            "ki": "0 <= ki < 16",
        },
        "bits_per_value": {
            # Original full-precision inputs
            "A": 16,         # FP16 activations
            "W": 16,         # FP16 weights
            # Per-TENSOR scales — FP32, approximated as per-row/per-col
            # (scalar projection [] crashes AccelForge auto-mapper,
            #  so we use [m] / [n] instead — negligible overhead)
            "Sga": 32,       # Global scale for activations [m]
            "Sgw": 32,       # Global scale for weights [n]
            # Tensor-scaled intermediates
            "Ascl": 16,      # Activations after global scaling
            "Wscl": 16,      # Weights after global scaling
            # Per-BLOCK scales — FP8 E4M3
            "Sba": 8,        # Block scale for activations [m, kb]
            "Sbw": 8,        # Block scale for weights [n, kb]
            # Quantized — FP4 E2M1
            "Aq": 4,         # Quantized activations
            "Wq": 4,         # Quantized weights
            # FP32 accumulator
            "Yraw": 32,      # FP4*FP4 partial sums
            "Ytmp": 32,      # After activation block rescale
            "Yblk": 32,      # After weight block rescale
            "Ytmp2": 32,     # After activation tensor rescale
            # Final output
            "Y": 16,         # FP16 after all rescaling
        },
        "einsums": [
            # ===== Activation quantization =====
            # 1. Per-tensor scale: reduce kb, ki -> per-row scale
            {
                "name": "TensorScaleA",
                "tensor_accesses": [
                    {"name": "A", "projection": ["m", "kb", "ki"], "density": 1.0},
                    {"name": "Sga", "projection": ["m"], "output": True},
                ],
            },
            # 2. Apply per-tensor scale
            {
                "name": "TensorQuantA",
                "tensor_accesses": [
                    {"name": "A", "projection": ["m", "kb", "ki"], "density": 1.0},
                    {"name": "Sga", "projection": ["m"], "density": 1.0},
                    {"name": "Ascl", "projection": ["m", "kb", "ki"], "output": True},
                ],
            },
            # 3. Per-block scale: reduce ki
            {
                "name": "BlockScaleA",
                "tensor_accesses": [
                    {"name": "Ascl", "projection": ["m", "kb", "ki"], "density": 1.0},
                    {"name": "Sba", "projection": ["m", "kb"], "output": True},
                ],
            },
            # 4. Quantize to FP4
            {
                "name": "BlockQuantA",
                "tensor_accesses": [
                    {"name": "Ascl", "projection": ["m", "kb", "ki"], "density": 1.0},
                    {"name": "Sba", "projection": ["m", "kb"], "density": 1.0},
                    {"name": "Aq", "projection": ["m", "kb", "ki"], "output": True},
                ],
            },
            # ===== Weight quantization =====
            # 5. Per-tensor scale: reduce kb, ki -> per-col scale
            {
                "name": "TensorScaleW",
                "tensor_accesses": [
                    {"name": "W", "projection": ["n", "kb", "ki"], "density": 1.0},
                    {"name": "Sgw", "projection": ["n"], "output": True},
                ],
            },
            # 6. Apply per-tensor scale
            {
                "name": "TensorQuantW",
                "tensor_accesses": [
                    {"name": "W", "projection": ["n", "kb", "ki"], "density": 1.0},
                    {"name": "Sgw", "projection": ["n"], "density": 1.0},
                    {"name": "Wscl", "projection": ["n", "kb", "ki"], "output": True},
                ],
            },
            # 7. Per-block scale: reduce ki
            {
                "name": "BlockScaleW",
                "tensor_accesses": [
                    {"name": "Wscl", "projection": ["n", "kb", "ki"], "density": 1.0},
                    {"name": "Sbw", "projection": ["n", "kb"], "output": True},
                ],
            },
            # 8. Quantize to FP4
            {
                "name": "BlockQuantW",
                "tensor_accesses": [
                    {"name": "Wscl", "projection": ["n", "kb", "ki"], "density": 1.0},
                    {"name": "Sbw", "projection": ["n", "kb"], "density": 1.0},
                    {"name": "Wq", "projection": ["n", "kb", "ki"], "output": True},
                ],
            },
            # ===== FP4 x FP4 MatMul, FP32 accumulate =====
            # 9. Yraw[m,n,kb] += Aq[m,kb,ki] * Wq[n,kb,ki]  (reduce ki)
            {
                "name": "MatMulNVFP4",
                "tensor_accesses": [
                    {"name": "Aq", "projection": ["m", "kb", "ki"], "density": 1.0},
                    {"name": "Wq", "projection": ["n", "kb", "ki"], "density": 1.0},
                    {"name": "Yraw", "projection": ["m", "n", "kb"], "output": True},
                ],
            },
            # ===== Rescale output (2 inputs each) =====
            # 10. Undo activation block scale
            {
                "name": "RescaleBlockA",
                "tensor_accesses": [
                    {"name": "Yraw", "projection": ["m", "n", "kb"], "density": 1.0},
                    {"name": "Sba", "projection": ["m", "kb"], "density": 1.0},
                    {"name": "Ytmp", "projection": ["m", "n", "kb"], "output": True},
                ],
            },
            # 11. Undo weight block scale
            {
                "name": "RescaleBlockW",
                "tensor_accesses": [
                    {"name": "Ytmp", "projection": ["m", "n", "kb"], "density": 1.0},
                    {"name": "Sbw", "projection": ["n", "kb"], "density": 1.0},
                    {"name": "Yblk", "projection": ["m", "n", "kb"], "output": True},
                ],
            },
            # 12. Undo activation tensor scale + reduce kb
            {
                "name": "RescaleTensorA",
                "tensor_accesses": [
                    {"name": "Yblk", "projection": ["m", "n", "kb"], "density": 1.0},
                    {"name": "Sga", "projection": ["m"], "density": 1.0},
                    {"name": "Ytmp2", "projection": ["m", "n"], "output": True},
                ],
            },
            # 13. Undo weight tensor scale
            {
                "name": "RescaleTensorW",
                "tensor_accesses": [
                    {"name": "Ytmp2", "projection": ["m", "n"], "density": 1.0},
                    {"name": "Sgw", "projection": ["n"], "density": 1.0},
                    {"name": "Y", "projection": ["m", "n"], "output": True},
                ],
            },
        ],
    }
}

nvfp4_full_workload_file = OUT_DIR / "workload_nvfp4_full.yaml"
dump_yaml(nvfp4_full_workload_file, nvfp4_full_workload)
print("Wrote full NVFP4 workload:", nvfp4_full_workload_file)
with open(nvfp4_full_workload_file) as f:
    print(f.read())
# Out:
# Wrote full NVFP4 workload: /home/workspace/workspace/lab_4/project4_m1/workload_nvfp4_full.yaml
# workload:
#   iteration_space_shape:
#     m: 0 <= m < 64
#     n: 0 <= n < 64
#     kb: 0 <= kb < 8
#     ki: 0 <= ki < 16
#   bits_per_value:
#     A: 16
#     W: 16
#     Sga: 32
#     Sgw: 32
#     Ascl: 16
#     Wscl: 16
#     Sba: 8
#     Sbw: 8
#     Aq: 4
#     Wq: 4
#     Yraw: 32
#     Ytmp: 32
#     Yblk: 32
#     Ytmp2: 32
#     Y: 16
#   einsums:
#   - name: TensorScaleA
#     tensor_accesses:
#     - name: A
#       projection:
#       - m
#       - kb
#       - ki
#       density: 1.0
#     - name: Sga
#       projection:
#       - m
#       output: true
#   - name: TensorQuantA
#     tensor_accesses:
#     - name: A
#       projection:
#       - m
#       - kb
#       - ki
#       density: 1.0
#     - name: Sga
#       projection:
#       - m
#       density: 1.0
#     - name: Ascl
#       projection:
#       - m
#       - kb
#       - ki
#       output: true
#   - name: BlockScaleA
#     tensor_accesses:
#     - name: Ascl
#       projection:
#       - m
#       - kb
#       - ki
#       density: 1.0
#     - name: Sba
#       projection:
#       - m
#       - kb
#       output: true
#   - name: BlockQuantA
#     tensor_accesses:
#     - name: Ascl
#       projection:
#       - m
#       - kb
#       - ki
#       density: 1.0
#     - name: Sba
#       projection:
#       - m
#       - kb
#       density: 1.0
#     - name: Aq
#       projection:
#       - m
#       - kb
#       - ki
#       output: true
#   - name: TensorScaleW
#     tensor_accesses:
#     - name: W
#       projection:
#       - n
#       - kb
#       - ki
#       density: 1.0
#     - name: Sgw
#       projection:
#       - n
#       output: true
#   - name: TensorQuantW
#     tensor_accesses:
#     - name: W
#       projection:
#       - n
#       - kb
#       - ki
#       density: 1.0
#     - name: Sgw
#       projection:
#       - n
#       density: 1.0
#     - name: Wscl
#       projection:
#       - n
#       - kb
#       - ki
#       output: true
#   - name: BlockScaleW
#     tensor_accesses:
#     - name: Wscl
#       projection:
#       - n
#       - kb
#       - ki
#       density: 1.0
#     - name: Sbw
#       projection:
#       - n
#       - kb
#       output: true
#   - name: BlockQuantW
#     tensor_accesses:
#     - name: Wscl
#       projection:
#       - n
#       - kb
#       - ki
#       density: 1.0
#     - name: Sbw
#       projection:
#       - n
#       - kb
#       density: 1.0
#     - name: Wq
#       projection:
#       - n
#       - kb
#       - ki
#       output: true
#   - name: MatMulNVFP4
#     tensor_accesses:
#     - name: Aq
#       projection:
#       - m
#       - kb
#       - ki
#       density: 1.0
#     - name: Wq
#       projection:
#       - n
#       - kb
#       - ki
#       density: 1.0
#     - name: Yraw
#       projection:
#       - m
#       - n
#       - kb
#       output: true
#   - name: RescaleBlockA
#     tensor_accesses:
#     - name: Yraw
#       projection:
#       - m
#       - n
#       - kb
#       density: 1.0
#     - name: Sba
#       projection:
#       - m
#       - kb
#       density: 1.0
#     - name: Ytmp
#       projection:
#       - m
#       - n
#       - kb
#       output: true
#   - name: RescaleBlockW
#     tensor_accesses:
#     - name: Ytmp
#       projection:
#       - m
#       - n
#       - kb
#       density: 1.0
#     - name: Sbw
#       projection:
#       - n
#       - kb
#       density: 1.0
#     - name: Yblk
#       projection:
#       - m
#       - n
#       - kb
#       output: true
#   - name: RescaleTensorA
#     tensor_accesses:
#     - name: Yblk
#       projection:
#       - m
#       - n
#       - kb
#       density: 1.0
#     - name: Sga
#       projection:
#       - m
#       density: 1.0
#     - name: Ytmp2
#       projection:
#       - m
#       - n
#       output: true
#   - name: RescaleTensorW
#     tensor_accesses:
#     - name: Ytmp2
#       projection:
#       - m
#       - n
#       density: 1.0
#     - name: Sgw
#       projection:
#       - n
#       density: 1.0
#     - name: Y
#       projection:
#       - m
#       - n
#       output: true

# %%
from accelforge.mapper import Metrics

nvfp4_full_mapping_file = OUT_DIR / "mapping_nvfp4_full.yaml"
nvfp4_full_mapping_text = """
mapping:
  nodes:
  - !Storage
    tensors: [A, W, Sga, Sgw, Ascl, Wscl, Sba, Sbw, Aq, Wq, Yraw, Ytmp, Yblk, Ytmp2, Y]
    component: DRAM
  - !Temporal
    rank_variable: m
    tile_shape: 8
  - !Temporal
    rank_variable: n
    tile_shape: 4
  - !Temporal
    rank_variable: kb
    tile_shape: 2
  - !Temporal
    rank_variable: ki
    tile_shape: 8
  - !Storage
    tensors: [A, W, Sga, Sgw, Ascl, Wscl, Sba, Sbw, Aq, Wq, Yraw, Ytmp, Yblk, Ytmp2, Y]
    component: GLB
  - !Temporal
    rank_variable: n
    tile_shape: 1
  - !Temporal
    rank_variable: kb
    tile_shape: 1
  - !Temporal
    rank_variable: ki
    tile_shape: 1
  - !Temporal
    rank_variable: m
    tile_shape: 1
  - !Spatial
    rank_variable: m
    tile_shape: 1
    name: X
    component: RF
  - !Compute
    einsum: TensorScaleA
    component: QuantMAC
  - !Compute
    einsum: TensorQuantA
    component: QuantMAC
  - !Compute
    einsum: BlockScaleA
    component: QuantMAC
  - !Compute
    einsum: BlockQuantA
    component: QuantMAC
  - !Compute
    einsum: TensorScaleW
    component: QuantMAC
  - !Compute
    einsum: TensorQuantW
    component: QuantMAC
  - !Compute
    einsum: BlockScaleW
    component: QuantMAC
  - !Compute
    einsum: BlockQuantW
    component: QuantMAC
  - !Compute
    einsum: MatMulNVFP4
    component: FP4MAC
  - !Compute
    einsum: RescaleBlockA
    component: RescaleMAC
  - !Compute
    einsum: RescaleBlockW
    component: RescaleMAC
  - !Compute
    einsum: RescaleTensorA
    component: RescaleMAC
  - !Compute
    einsum: RescaleTensorW
    component: RescaleMAC
""".strip()

nvfp4_full_mapping_file.write_text(nvfp4_full_mapping_text)
print("Wrote full NVFP4 mapping:", nvfp4_full_mapping_file)

if AF_AVAILABLE and ARCH_FILE.exists() and nvfp4_full_workload_file.exists():
    spec_nvfp4 = af.Spec.from_yaml(str(ARCH_FILE), str(nvfp4_full_workload_file), jinja_parse_data=ARCH_PARAMS)
    spec_nvfp4.mapper.metrics = Metrics.LATENCY | Metrics.ENERGY
    print("Full NVFP4 spec parsed successfully.")

    try:
        all_nvfp4_mappings = spec_nvfp4.map_workload_to_arch()
        print("Full NVFP4 auto-mapping completed.")
        print(f"Found {len(all_nvfp4_mappings.data)} mappings")

        # Select best mapping by minimum EDP (energy x latency)
        df = all_nvfp4_mappings.data
        energy_cols = [c for c in df.columns if 'energy' in c.lower()]
        latency_cols = [c for c in df.columns if 'latency' in c.lower()]
        print(f"Energy columns: {energy_cols}")
        print(f"Latency columns: {latency_cols}")

        best_idx = 0
        if energy_cols and latency_cols:
            edp = df[energy_cols[0]] * df[latency_cols[0]]
            best_idx = edp.idxmin()

        nvfp4_full_result = all_nvfp4_mappings[best_idx]
        print(f"Best mapping index: {best_idx}")
        print(f"Energy: {nvfp4_full_result.energy()} pJ")
        print(f"Latency: {nvfp4_full_result.latency()} cycles")

        # Export and save the auto-generated mapping
        best_mapping_yaml = nvfp4_full_result.mapping().to_yaml()
        auto_mapping_file = OUT_DIR / "mapping_nvfp4_full_auto.yaml"
        auto_mapping_file.write_text(best_mapping_yaml)
        print(f"\nSaved auto-generated mapping to: {auto_mapping_file}")
        print("\n=== Auto-generated mapping ===")
        print(best_mapping_yaml)
    except Exception as e:
        import traceback
        print("Full NVFP4 parse succeeded, but map_workload_to_arch() failed:")
        traceback.print_exc()
else:
    print("Skipped Spec.from_yaml/map_workload_to_arch().")
    print("AF_AVAILABLE:", AF_AVAILABLE)
    print("arch exists:", ARCH_FILE.exists(), ARCH_FILE)
    print("workload exists:", nvfp4_full_workload_file.exists(), nvfp4_full_workload_file)
# Out:
# Wrote full NVFP4 mapping: /home/workspace/workspace/lab_4/project4_m1/mapping_nvfp4_full.yaml
# Full NVFP4 spec parsed successfully.
# Getting energy, latency, and leak power for components running RescaleTensorW: 100%|██████████| 13/13 [00:00<00:00, 55.75it/s]
# Generating pmapping templates for compute QuantMAC Einsum TensorScaleA: 40it [00:00, 203.12it/s]]]
# Generating pmapping templates for compute QuantMAC Einsum TensorScaleW: 40it [00:00, 203.24it/s]
# Generating pmapping templates for compute QuantMAC Einsum BlockScaleW: 65it [00:00, 187.13it/s]]
# Generating pmapping templates for compute QuantMAC Einsum BlockScaleA: 65it [00:00, 170.57it/s]]]]
# Generating pmapping templates for compute FP4MAC Einsum TensorScaleW: 40it [00:00, 156.12it/s]s]]]
# Generating pmapping templates for compute FP4MAC Einsum TensorScaleA: 40it [00:00, 152.64it/s]
# Generating pmapping templates for compute FP4MAC Einsum BlockScaleW: 65it [00:00, 230.38it/s]t/s]s]
# Generating pmapping templates for compute RescaleMAC Einsum TensorScaleW: 40it [00:00, 215.19it/s]]
# Generating pmapping templates for compute RescaleMAC Einsum TensorScaleA: 40it [00:00, 211.63it/s]
# Generating pmapping templates for compute FP4MAC Einsum BlockScaleA: 65it [00:00, 222.20it/s]
# Generating pmapping templates for compute FP16MAC Einsum TensorScaleA: 40it [00:00, 220.75it/s]/s]]
# Generating pmapping templates for compute FP16MAC Einsum TensorScaleW: 40it [00:00, 201.02it/s]/s]
# Generating pmapping templates for compute RescaleMAC Einsum BlockScaleW: 65it [00:00, 171.40it/s]s]
# Generating pmapping templates for compute RescaleMAC Einsum BlockScaleA: 65it [00:00, 176.96it/s]]]
# Generating pmapping templates for compute FP16MAC Einsum BlockScaleW: 65it [00:00, 230.91it/s]t/s]]
# Generating pmapping templates for compute FP16MAC Einsum BlockScaleA: 65it [00:00, 223.73it/s]/s]s]
# Generating pmapping templates for compute QuantMAC Einsum RescaleTensorW: 736it [00:03, 210.00it/s]
# Generating pmapping templates for compute QuantMAC Einsum TensorQuantW: 736it [00:03, 211.13it/s]
# Generating pmapping templates for compute QuantMAC Einsum TensorQuantA: 736it [00:03, 199.31it/s]s]
# Generating pmapping templates for compute QuantMAC Einsum BlockQuantA: 1264it [00:05, 216.07it/s]/s]
# Generating pmapping templates for compute QuantMAC Einsum MatMulNVFP4: 1264it [00:05, 213.98it/s]/s]
# Generating pmapping templates for compute QuantMAC Einsum RescaleBlockW: 1264it [00:05, 214.88it/s]
# Generating pmapping templates for compute QuantMAC Einsum RescaleBlockA: 1264it [00:06, 210.48it/s]
# Generating pmapping templates for compute QuantMAC Einsum RescaleTensorA: 1264it [00:06, 209.13it/s]
# Generating pmapping templates for compute QuantMAC Einsum BlockQuantW: 1264it [00:06, 202.54it/s]
# Generating pmapping templates for compute FP4MAC Einsum RescaleTensorW: 736it [00:03, 207.13it/s]
# Generating pmapping templates for compute FP4MAC Einsum TensorQuantA: 736it [00:03, 195.48it/s]it/s]
# Generating pmapping templates for compute FP4MAC Einsum TensorQuantW: 736it [00:03, 185.65it/s]]]
# Generating pmapping templates for compute RescaleMAC Einsum RescaleTensorW: 736it [00:03, 239.17it/s]
# Generating pmapping templates for compute RescaleMAC Einsum TensorQuantA: 736it [00:03, 228.65it/s]
# Generating pmapping templates for compute RescaleMAC Einsum TensorQuantW: 736it [00:03, 232.51it/s]
# Generating pmapping templates for compute FP4MAC Einsum RescaleBlockW: 1264it [00:05, 216.55it/s]]
# Generating pmapping templates for compute FP4MAC Einsum BlockQuantA: 1264it [00:06, 208.81it/s]t/s]
# Generating pmapping templates for compute FP4MAC Einsum RescaleBlockA: 1264it [00:05, 211.14it/s]]
# Generating pmapping templates for compute FP4MAC Einsum MatMulNVFP4: 1264it [00:06, 205.31it/s]]]s]
# Generating pmapping templates for compute FP4MAC Einsum RescaleTensorA: 1264it [00:06, 206.29it/s]]
# Generating pmapping templates for compute FP4MAC Einsum BlockQuantW: 1264it [00:06, 207.10it/s]/s]s]
# Generating pmapping templates for compute FP16MAC Einsum RescaleTensorW: 736it [00:03, 241.24it/s]s]]
# Generating pmapping templates for compute FP16MAC Einsum TensorQuantW: 736it [00:03, 202.66it/s]it/s]
# Generating pmapping templates for compute FP16MAC Einsum TensorQuantA: 736it [00:03, 186.56it/s]it/s]
# Generating pmapping templates for compute RescaleMAC Einsum BlockQuantA: 1264it [00:05, 229.35it/s]s]]
# Generating pmapping templates for compute RescaleMAC Einsum RescaleTensorA: 1264it [00:05, 229.88it/s]
# Generating pmapping templates for compute RescaleMAC Einsum RescaleBlockW: 1264it [00:05, 210.86it/s]
# Generating pmapping templates for compute RescaleMAC Einsum MatMulNVFP4: 1264it [00:05, 219.89it/s]s]
# Generating pmapping templates for compute RescaleMAC Einsum BlockQuantW: 1264it [00:05, 229.74it/s]
# Generating pmapping templates for compute RescaleMAC Einsum RescaleBlockA: 1264it [00:05, 214.08it/s]
# Generating pmapping templates for compute FP16MAC Einsum BlockQuantA: 1264it [00:04, 279.27it/s]s]]
# Generating pmapping templates for compute FP16MAC Einsum RescaleTensorA: 1264it [00:04, 281.32it/s]
# Generating pmapping templates for compute FP16MAC Einsum RescaleBlockW: 1264it [00:04, 270.58it/s]
# Generating pmapping templates for compute FP16MAC Einsum MatMulNVFP4: 1264it [00:04, 271.17it/s]
# Generating pmapping templates for compute FP16MAC Einsum BlockQuantW: 1264it [00:04, 268.20it/s]s]
# Generating pmapping templates for compute FP16MAC Einsum RescaleBlockA: 1264it [00:04, 270.90it/s]
# Generating jobs: 100%|██████████| 13/13 [00:58<00:00,  4.52s/it]
# Einsum TensorScaleA has 160 pmapping templates:
# 	0	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  QuantMAC computes TensorScaleA
# 	1	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] QuantMAC computes TensorScaleA
# 	2	[A in DRAM] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  QuantMAC computes TensorScaleA
# 	3	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorScaleA
# 	4	[A in DRAM] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] QuantMAC computes TensorScaleA
# 	5	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  QuantMAC computes TensorScaleA
# 	6	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  QuantMAC computes TensorScaleA
# 	7	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] QuantMAC computes TensorScaleA
# 	8	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] QuantMAC computes TensorScaleA
# 	9	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  QuantMAC computes TensorScaleA
# 	10	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  QuantMAC computes TensorScaleA
# 	11	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorScaleA
# 	12	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] QuantMAC computes TensorScaleA
# 	13	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorScaleA
# 	14	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] QuantMAC computes TensorScaleA
# 	15	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP4MAC computes TensorScaleA
# 	16	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP4MAC computes TensorScaleA
# 	17	[A in DRAM] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP4MAC computes TensorScaleA
# 	18	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP4MAC computes TensorScaleA
# 	19	[A in DRAM] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP4MAC computes TensorScaleA
# 	20	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP4MAC computes TensorScaleA
# 	21	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP4MAC computes TensorScaleA
# 	22	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP4MAC computes TensorScaleA
# 	23	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP4MAC computes TensorScaleA
# 	24	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP4MAC computes TensorScaleA
# 	25	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP4MAC computes TensorScaleA
# 	26	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP4MAC computes TensorScaleA
# 	27	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP4MAC computes TensorScaleA
# 	28	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP4MAC computes TensorScaleA
# 	29	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP4MAC computes TensorScaleA
# 	30	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  RescaleMAC computes TensorScaleA
# 	31	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] RescaleMAC computes TensorScaleA
# 	32	[A in DRAM] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  RescaleMAC computes TensorScaleA
# 	33	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  RescaleMAC computes TensorScaleA
# 	34	[A in DRAM] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] RescaleMAC computes TensorScaleA
# 	35	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  RescaleMAC computes TensorScaleA
# 	36	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  RescaleMAC computes TensorScaleA
# 	37	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] RescaleMAC computes TensorScaleA
# 	38	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] RescaleMAC computes TensorScaleA
# 	39	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  RescaleMAC computes TensorScaleA
# 	40	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  RescaleMAC computes TensorScaleA
# 	41	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  RescaleMAC computes TensorScaleA
# 	42	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] RescaleMAC computes TensorScaleA
# 	43	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  RescaleMAC computes TensorScaleA
# 	44	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] RescaleMAC computes TensorScaleA
# 	45	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP16MAC computes TensorScaleA
# 	46	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP16MAC computes TensorScaleA
# 	47	[A in DRAM] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP16MAC computes TensorScaleA
# 	48	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP16MAC computes TensorScaleA
# 	49	[A in DRAM] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP16MAC computes TensorScaleA
# 	50	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP16MAC computes TensorScaleA
# 	51	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP16MAC computes TensorScaleA
# 	52	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP16MAC computes TensorScaleA
# 	53	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP16MAC computes TensorScaleA
# 	54	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP16MAC computes TensorScaleA
# 	55	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP16MAC computes TensorScaleA
# 	56	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP16MAC computes TensorScaleA
# 	57	[A in DRAM] T-m  [A in GLB] [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP16MAC computes TensorScaleA
# 	58	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP16MAC computes TensorScaleA
# 	59	[A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP16MAC computes TensorScaleA
# 	60	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  QuantMAC computes TensorScaleA
# 	61	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] QuantMAC computes TensorScaleA
# 	62	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  QuantMAC computes TensorScaleA
# 	63	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorScaleA
# 	64	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] QuantMAC computes TensorScaleA
# 	65	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  QuantMAC computes TensorScaleA
# 	66	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] QuantMAC computes TensorScaleA
# 	67	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  QuantMAC computes TensorScaleA
# 	68	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorScaleA
# 	69	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] QuantMAC computes TensorScaleA
# 	70	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  QuantMAC computes TensorScaleA
# 	71	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] QuantMAC computes TensorScaleA
# 	72	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  QuantMAC computes TensorScaleA
# 	73	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorScaleA
# 	74	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] QuantMAC computes TensorScaleA
# 	75	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  QuantMAC computes TensorScaleA
# 	76	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  QuantMAC computes TensorScaleA
# 	77	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] QuantMAC computes TensorScaleA
# 	78	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] QuantMAC computes TensorScaleA
# 	79	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  QuantMAC computes TensorScaleA
# 	80	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  QuantMAC computes TensorScaleA
# 	81	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorScaleA
# 	82	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] QuantMAC computes TensorScaleA
# 	83	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorScaleA
# 	84	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] QuantMAC computes TensorScaleA
# 	85	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP4MAC computes TensorScaleA
# 	86	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP4MAC computes TensorScaleA
# 	87	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP4MAC computes TensorScaleA
# 	88	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP4MAC computes TensorScaleA
# 	89	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP4MAC computes TensorScaleA
# 	90	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP4MAC computes TensorScaleA
# 	91	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP4MAC computes TensorScaleA
# 	92	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP4MAC computes TensorScaleA
# 	93	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP4MAC computes TensorScaleA
# 	94	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP4MAC computes TensorScaleA
# 	95	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP4MAC computes TensorScaleA
# 	96	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP4MAC computes TensorScaleA
# 	97	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP4MAC computes TensorScaleA
# 	98	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP4MAC computes TensorScaleA
# 	99	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP4MAC computes TensorScaleA
# 	100	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP4MAC computes TensorScaleA
# 	101	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP4MAC computes TensorScaleA
# 	102	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP4MAC computes TensorScaleA
# 	103	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP4MAC computes TensorScaleA
# 	104	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP4MAC computes TensorScaleA
# 	105	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP4MAC computes TensorScaleA
# 	106	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP4MAC computes TensorScaleA
# 	107	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP4MAC computes TensorScaleA
# 	108	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP4MAC computes TensorScaleA
# 	109	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP4MAC computes TensorScaleA
# 	110	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  RescaleMAC computes TensorScaleA
# 	111	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] RescaleMAC computes TensorScaleA
# 	112	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  RescaleMAC computes TensorScaleA
# 	113	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  RescaleMAC computes TensorScaleA
# 	114	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] RescaleMAC computes TensorScaleA
# 	115	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  RescaleMAC computes TensorScaleA
# 	116	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] RescaleMAC computes TensorScaleA
# 	117	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  RescaleMAC computes TensorScaleA
# 	118	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  RescaleMAC computes TensorScaleA
# 	119	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] RescaleMAC computes TensorScaleA
# 	120	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  RescaleMAC computes TensorScaleA
# 	121	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] RescaleMAC computes TensorScaleA
# 	122	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  RescaleMAC computes TensorScaleA
# 	123	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  RescaleMAC computes TensorScaleA
# 	124	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] RescaleMAC computes TensorScaleA
# 	125	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  RescaleMAC computes TensorScaleA
# 	126	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  RescaleMAC computes TensorScaleA
# 	127	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] RescaleMAC computes TensorScaleA
# 	128	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] RescaleMAC computes TensorScaleA
# 	129	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  RescaleMAC computes TensorScaleA
# 	130	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  RescaleMAC computes TensorScaleA
# 	131	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  RescaleMAC computes TensorScaleA
# 	132	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] RescaleMAC computes TensorScaleA
# 	133	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  RescaleMAC computes TensorScaleA
# 	134	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] RescaleMAC computes TensorScaleA
# 	135	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP16MAC computes TensorScaleA
# 	136	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP16MAC computes TensorScaleA
# 	137	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP16MAC computes TensorScaleA
# 	138	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP16MAC computes TensorScaleA
# 	139	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP16MAC computes TensorScaleA
# 	140	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP16MAC computes TensorScaleA
# 	141	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP16MAC computes TensorScaleA
# 	142	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP16MAC computes TensorScaleA
# 	143	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP16MAC computes TensorScaleA
# 	144	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP16MAC computes TensorScaleA
# 	145	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP16MAC computes TensorScaleA
# 	146	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP16MAC computes TensorScaleA
# 	147	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP16MAC computes TensorScaleA
# 	148	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP16MAC computes TensorScaleA
# 	149	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP16MAC computes TensorScaleA
# 	150	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP16MAC computes TensorScaleA
# 	151	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP16MAC computes TensorScaleA
# 	152	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP16MAC computes TensorScaleA
# 	153	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP16MAC computes TensorScaleA
# 	154	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP16MAC computes TensorScaleA
# 	155	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP16MAC computes TensorScaleA
# 	156	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP16MAC computes TensorScaleA
# 	157	[Sga in DRAM] [A in DRAM] T-kb  T-ki  T-m  [A in GLB] [Sga in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP16MAC computes TensorScaleA
# 	158	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP16MAC computes TensorScaleA
# 	159	[Sga in DRAM] [A in DRAM] T-m  [Sga in GLB] T-kb  T-ki  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP16MAC computes TensorScaleA
# Einsum TensorQuantA has 2944 pmapping templates:
# 	0	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  QuantMAC computes TensorQuantA
# 	1	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] QuantMAC computes TensorQuantA
# 	2	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] QuantMAC computes TensorQuantA
# 	3	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	4	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Ascl in RF] QuantMAC computes TensorQuantA
# 	5	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [A in RF] QuantMAC computes TensorQuantA
# 	6	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	7	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] QuantMAC computes TensorQuantA
# 	8	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	9	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [Ascl in RF] QuantMAC computes TensorQuantA
# 	10	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Ascl in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	11	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  [Ascl in RF] QuantMAC computes TensorQuantA
# 	12	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [A in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	13	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [Sga in RF] T-kb  T-ki  [A in RF] QuantMAC computes TensorQuantA
# 	14	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] [Ascl in RF] QuantMAC computes TensorQuantA
# 	15	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [Ascl in RF] [A in RF] QuantMAC computes TensorQuantA
# 	16	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  QuantMAC computes TensorQuantA
# 	17	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  QuantMAC computes TensorQuantA
# 	18	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  QuantMAC computes TensorQuantA
# 	19	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] QuantMAC computes TensorQuantA
# 	20	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] QuantMAC computes TensorQuantA
# 	21	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] QuantMAC computes TensorQuantA
# 	22	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] QuantMAC computes TensorQuantA
# 	23	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] QuantMAC computes TensorQuantA
# 	24	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] QuantMAC computes TensorQuantA
# 	25	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	26	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	27	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	28	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Ascl in RF] QuantMAC computes TensorQuantA
# 	29	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [A in RF] QuantMAC computes TensorQuantA
# 	30	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Ascl in RF] QuantMAC computes TensorQuantA
# 	31	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [A in RF] QuantMAC computes TensorQuantA
# 	32	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Ascl in RF] QuantMAC computes TensorQuantA
# 	33	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [A in RF] QuantMAC computes TensorQuantA
# 	34	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	35	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] QuantMAC computes TensorQuantA
# 	36	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	37	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] QuantMAC computes TensorQuantA
# 	38	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	39	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] QuantMAC computes TensorQuantA
# 	40	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	41	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [Ascl in RF] QuantMAC computes TensorQuantA
# 	42	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	43	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [Ascl in RF] QuantMAC computes TensorQuantA
# 	44	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	45	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [Ascl in RF] QuantMAC computes TensorQuantA
# 	46	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Ascl in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	47	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  [Ascl in RF] QuantMAC computes TensorQuantA
# 	48	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [A in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	49	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [Sga in RF] T-kb  T-ki  [A in RF] QuantMAC computes TensorQuantA
# 	50	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] [Ascl in RF] QuantMAC computes TensorQuantA
# 	51	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [Ascl in RF] [A in RF] QuantMAC computes TensorQuantA
# 	52	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Ascl in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	53	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  [Ascl in RF] QuantMAC computes TensorQuantA
# 	54	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [A in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	55	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [Sga in RF] T-kb  T-ki  [A in RF] QuantMAC computes TensorQuantA
# 	56	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] [Ascl in RF] QuantMAC computes TensorQuantA
# 	57	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [Ascl in RF] [A in RF] QuantMAC computes TensorQuantA
# 	58	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Ascl in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	59	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  [Ascl in RF] QuantMAC computes TensorQuantA
# 	60	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [A in RF] [Sga in RF] T-kb  T-ki  QuantMAC computes TensorQuantA
# 	61	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [Sga in RF] T-kb  T-ki  [A in RF] QuantMAC computes TensorQuantA
# 	62	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] [Ascl in RF] QuantMAC computes TensorQuantA
# 	63	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [Ascl in RF] [A in RF] QuantMAC computes TensorQuantA
# 	64	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP4MAC computes TensorQuantA
# 	65	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP4MAC computes TensorQuantA
# 	66	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] FP4MAC computes TensorQuantA
# 	67	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP4MAC computes TensorQuantA
# 	68	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Ascl in RF] FP4MAC computes TensorQuantA
# 	69	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [A in RF] FP4MAC computes TensorQuantA
# 	70	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  FP4MAC computes TensorQuantA
# 	71	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] FP4MAC computes TensorQuantA
# 	72	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [Sga in RF] T-kb  T-ki  FP4MAC computes TensorQuantA
# 	73	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [Ascl in RF] FP4MAC computes TensorQuantA
# 	74	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Ascl in RF] [Sga in RF] T-kb  T-ki  FP4MAC computes TensorQuantA
# 	75	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Sga in RF] T-kb  T-ki  [Ascl in RF] FP4MAC computes TensorQuantA
# 	76	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [A in RF] [Sga in RF] T-kb  T-ki  FP4MAC computes TensorQuantA
# 	77	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [Sga in RF] T-kb  T-ki  [A in RF] FP4MAC computes TensorQuantA
# 	78	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [A in RF] [Ascl in RF] FP4MAC computes TensorQuantA
# 	79	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  [Ascl in RF] [A in RF] FP4MAC computes TensorQuantA
# 	80	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP4MAC computes TensorQuantA
# 	81	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP4MAC computes TensorQuantA
# 	82	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  FP4MAC computes TensorQuantA
# 	83	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP4MAC computes TensorQuantA
# 	84	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP4MAC computes TensorQuantA
# 	85	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] FP4MAC computes TensorQuantA
# 	86	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] FP4MAC computes TensorQuantA
# 	87	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] FP4MAC computes TensorQuantA
# 	88	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] FP4MAC computes TensorQuantA
# 	89	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP4MAC computes TensorQuantA
# 	90	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP4MAC computes TensorQuantA
# 	91	[A in DRAM] T-m  [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  [A in GLB] S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Sga in RF] T-kb  T-ki  FP4MAC computes TensorQuantA
# 	92	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Ascl in RF] FP4MAC computes TensorQuantA
# 	93	[A in DRAM] T-m  [A in GLB] [Ascl in GLB] T-m  [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [A in RF] FP4MAC computes TensorQuantA
# 	94	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [A in RF] [Ascl in RF] FP4MAC computes TensorQuantA
# 	95	[A in DRAM] T-m  [Ascl in GLB] T-m  [A in GLB] [Sga in GLB] T-kb  T-ki  T-m  S-Y-m  S-Y-ki  S-Y-kb  S-X-m  S-X-ki  S-X-kb  [Ascl in RF] [A in RF] FP4MAC computes TensorQuantA
# ...
#                 area: 6e-11
#                 total_area: null
#                 area_scale: 1
#                 leak_power: 0
#                 total_leak_power: 0
#                 leak_power_scale: 1
#                 energy_scale: 1
#                 total_latency: sum(*action2latency.values())
#                 latency_scale: 1
#                 n_parallel_instances: 1
#                 extra_attributes_for_component_model: {}
#                 compute_optimization: []
#       - nodes:
#           - purposes:
#               - Sgw
#               - Sga
#               - Sbw
#             resource: GLB
#             persistent: false
#           - purposes:
#               - Ytmp
#               - Yblk
#             resource: DRAM
#             persistent: false
#           - rank_variable: kb
#             tile_shape: 1
#             initial_tile_shape: null
#           - rank_variable: n
#             tile_shape: 1
#             initial_tile_shape: null
#           - rank_variable: m
#             tile_shape: 8
#             initial_tile_shape: null
#             name: Y
#             component: RF
#             component_object: {}
#           - rank_variable: m
#             tile_shape: 1
#             initial_tile_shape: null
#             name: X
#             component: RF
#             component_object: {}
#           - einsum: RescaleBlockW
#             component: FP4MAC
#             component_object:
#                 name: FP4MAC
#                 spatial: []
#                 component_class: null
#                 component_model: null
#                 component_modeling_log:
#                   - Calculating energy for FP4MAC action compute.
#                   - Setting FP4MAC energy to action.energy=0.2
#                   - Calculating latency for FP4MAC action compute.
#                   - Setting FP4MAC latency to action.latency=1
#                   - Using predefined leak power value self.leak_power=0
#                   - Calculating energy for FP4MAC action compute.
#                   - Setting FP4MAC energy to action.energy=0.2
#                   - Calculating latency for FP4MAC action compute.
#                   - Setting FP4MAC latency to action.latency=1
#                   - Using predefined leak power value self.leak_power=0
#                 actions:
#                   - name: compute
#                     energy: 0.2
#                     energy_scale: 1
#                     latency: 1
#                     latency_scale: 1
#                     extra_attributes_for_component_model: {}
#                 enabled: true
#                 area: 6e-11
#                 total_area: null
#                 area_scale: 1
#                 leak_power: 0
#                 total_leak_power: 0
#                 leak_power_scale: 1
#                 energy_scale: 1
#                 total_latency: sum(*action2latency.values())
#                 latency_scale: 1
#                 n_parallel_instances: 1
#                 extra_attributes_for_component_model: {}
#                 compute_optimization: []
#       - nodes:
#           - purposes:
#               - Sgw
#               - Sga
#             resource: GLB
#             persistent: false
#           - purposes:
#               - Ytmp2
#               - Yblk
#             resource: DRAM
#             persistent: false
#           - rank_variable: m
#             tile_shape: 1
#             initial_tile_shape: null
#           - rank_variable: n
#             tile_shape: 8
#             initial_tile_shape: null
#           - tensors:
#               - Ytmp2
#             component: GLB
#             component_object:
#                 name: GLB
#                 spatial: []
#                 component_class: null
#                 component_model: null
#                 component_modeling_log:
#                   - Calculating energy for GLB action read.
#                   - Setting GLB energy to action.energy=5
#                   - Calculating energy for GLB action write.
#                   - Setting GLB energy to action.energy=5
#                   - Calculating energy for GLB action metadata_read.
#                   - Setting GLB energy to action.energy=2
#                   - Calculating energy for GLB action metadata_write.
#                   - Setting GLB energy to action.energy=2
#                   - Calculating latency for GLB action read.
#                   - Setting GLB latency to action.latency=0
#                   - Calculating latency for GLB action write.
#                   - Setting GLB latency to action.latency=0
#                   - Calculating latency for GLB action metadata_read.
#                   - Setting GLB latency to action.latency=0
#                   - Calculating latency for GLB action metadata_write.
#                   - Setting GLB latency to action.latency=0
#                   - Using predefined leak power value self.leak_power=0
#                   - Calculating energy for GLB action read.
#                   - Setting GLB energy to action.energy=5
#                   - Calculating energy for GLB action write.
#                   - Setting GLB energy to action.energy=5
#                   - Calculating energy for GLB action metadata_read.
#                   - Setting GLB energy to action.energy=2
#                   - Calculating energy for GLB action metadata_write.
#                   - Setting GLB energy to action.energy=2
#                   - Calculating latency for GLB action read.
#                   - Setting GLB latency to action.latency=0
#                   - Calculating latency for GLB action write.
#                   - Setting GLB latency to action.latency=0
#                   - Calculating latency for GLB action metadata_read.
#                   - Setting GLB latency to action.latency=0
#                   - Calculating latency for GLB action metadata_write.
#                   - Setting GLB latency to action.latency=0
#                   - Using predefined leak power value self.leak_power=0
#                 actions:
#                   - name: read
#                     energy: 5
#                     energy_scale: 1
#                     latency: 0
#                     latency_scale: 1
#                     extra_attributes_for_component_model: {}
#                     bits_per_action: 32
#                   - name: write
#                     energy: 5
#                     energy_scale: 1
#                     latency: 0
#                     latency_scale: 1
#                     extra_attributes_for_component_model: {}
#                     bits_per_action: 32
#                   - name: metadata_read
#                     energy: 2
#                     energy_scale: 1
#                     latency: 0
#                     latency_scale: 1
#                     extra_attributes_for_component_model: {}
#                     bits_per_action: 16
#                   - name: metadata_write
#                     energy: 2
#                     energy_scale: 1
#                     latency: 0
#                     latency_scale: 1
#                     extra_attributes_for_component_model: {}
#                     bits_per_action: 16
#                 enabled: true
#                 area: 3.8797312e-07
#                 total_area: null
#                 area_scale: 1
#                 leak_power: 0
#                 total_leak_power: 0
#                 leak_power_scale: 1
#                 energy_scale: 1
#                 total_latency: ceil(max(total_read_actions / 32,
#                     total_write_actions / 32))
#                 latency_scale: 1
#                 n_parallel_instances: 1
#                 extra_attributes_for_component_model: {}
#             persistent: false
#           - purposes:
#               - Ytmp2
#             resource: GLB
#             persistent: false
#           - rank_variable: n
#             tile_shape: 1
#             initial_tile_shape: null
#             name: Y
#             component: RF
#             component_object: {}
#           - rank_variable: kb
#             tile_shape: 1
#             initial_tile_shape: null
#             name: X
#             component: RF
#             component_object: {}
#           - einsum: RescaleTensorA
#             component: FP4MAC
#             component_object:
#                 name: FP4MAC
#                 spatial: []
#                 component_class: null
#                 component_model: null
#                 component_modeling_log:
#                   - Calculating energy for FP4MAC action compute.
#                   - Setting FP4MAC energy to action.energy=0.2
#                   - Calculating latency for FP4MAC action compute.
#                   - Setting FP4MAC latency to action.latency=1
#                   - Using predefined leak power value self.leak_power=0
#                   - Calculating energy for FP4MAC action compute.
#                   - Setting FP4MAC energy to action.energy=0.2
#                   - Calculating latency for FP4MAC action compute.
#                   - Setting FP4MAC latency to action.latency=1
#                   - Using predefined leak power value self.leak_power=0
#                 actions:
#                   - name: compute
#                     energy: 0.2
#                     energy_scale: 1
#                     latency: 1
#                     latency_scale: 1
#                     extra_attributes_for_component_model: {}
#                 enabled: true
#                 area: 6e-11
#                 total_area: null
#                 area_scale: 1
#                 leak_power: 0
#                 total_leak_power: 0
#                 leak_power_scale: 1
#                 energy_scale: 1
#                 total_latency: sum(*action2latency.values())
#                 latency_scale: 1
#                 n_parallel_instances: 1
#                 extra_attributes_for_component_model: {}
#                 compute_optimization: []
#       - nodes:
#           - tensors:
#               - Y
#             component: DRAM
#             component_object:
#                 name: DRAM
#                 spatial: []
#                 component_class: null
#                 component_model: null
#                 component_modeling_log:
#                   - Calculating energy for DRAM action read.
#                   - Setting DRAM energy to action.energy=10
#                   - Calculating energy for DRAM action write.
#                   - Setting DRAM energy to action.energy=10
#                   - Calculating energy for DRAM action metadata_read.
#                   - Setting DRAM energy to action.energy=2
#                   - Calculating energy for DRAM action metadata_write.
#                   - Setting DRAM energy to action.energy=2
#                   - Calculating latency for DRAM action read.
#                   - Setting DRAM latency to action.latency=0
#                   - Calculating latency for DRAM action write.
#                   - Setting DRAM latency to action.latency=0
#                   - Calculating latency for DRAM action metadata_read.
#                   - Setting DRAM latency to action.latency=0
#                   - Calculating latency for DRAM action metadata_write.
#                   - Setting DRAM latency to action.latency=0
#                   - Using predefined leak power value self.leak_power=0
#                   - Calculating energy for DRAM action read.
#                   - Setting DRAM energy to action.energy=10
#                   - Calculating energy for DRAM action write.
#                   - Setting DRAM energy to action.energy=10
#                   - Calculating energy for DRAM action metadata_read.
#                   - Setting DRAM energy to action.energy=2
#                   - Calculating energy for DRAM action metadata_write.
#                   - Setting DRAM energy to action.energy=2
#                   - Calculating latency for DRAM action read.
#                   - Setting DRAM latency to action.latency=0
#                   - Calculating latency for DRAM action write.
#                   - Setting DRAM latency to action.latency=0
#                   - Calculating latency for DRAM action metadata_read.
#                   - Setting DRAM latency to action.latency=0
#                   - Calculating latency for DRAM action metadata_write.
#                   - Setting DRAM latency to action.latency=0
#                   - Using predefined leak power value self.leak_power=0
#                 actions:
#                   - name: read
#                     energy: 10
#                     energy_scale: 1
#                     latency: 0
#                     latency_scale: 1
#                     extra_attributes_for_component_model: {}
#                     bits_per_action: 64
#                   - name: write
#                     energy: 10
#                     energy_scale: 1
#                     latency: 0
#                     latency_scale: 1
#                     extra_attributes_for_component_model: {}
#                     bits_per_action: 64
#                   - name: metadata_read
#                     energy: 2
#                     energy_scale: 1
#                     latency: 0
#                     latency_scale: 1
#                     extra_attributes_for_component_model: {}
#                     bits_per_action: 16
#                   - name: metadata_write
#                     energy: 2
#                     energy_scale: 1
#                     latency: 0
#                     latency_scale: 1
#                     extra_attributes_for_component_model: {}
#                     bits_per_action: 16
#                 enabled: true
#                 area: 0
#                 total_area: null
#                 area_scale: 1
#                 leak_power: 0
#                 total_leak_power: 0
#                 leak_power_scale: 1
#                 energy_scale: 1
#                 total_latency: ceil(max((read_actions + metadata_read_actions) /
#                     8, (write_actions + metadata_write_actions) / 8))
#                 latency_scale: 1
#                 n_parallel_instances: 1
#                 extra_attributes_for_component_model: {}
#             persistent: false
#           - purposes:
#               - Ytmp2
#               - Y
#             resource: DRAM
#             persistent: false
#           - purposes:
#               - Sgw
#             resource: GLB
#             persistent: false
#           - rank_variable: n
#             tile_shape: 1
#             initial_tile_shape: null
#           - rank_variable: m
#             tile_shape: 8
#             initial_tile_shape: null
#             name: Y
#             component: RF
#             component_object: {}
#           - rank_variable: m
#             tile_shape: 1
#             initial_tile_shape: null
#             name: X
#             component: RF
#             component_object: {}
#           - einsum: RescaleTensorW
#             component: FP4MAC
#             component_object:
#                 name: FP4MAC
#                 spatial: []
#                 component_class: null
#                 component_model: null
#                 component_modeling_log:
#                   - Calculating energy for FP4MAC action compute.
#                   - Setting FP4MAC energy to action.energy=0.2
#                   - Calculating latency for FP4MAC action compute.
#                   - Setting FP4MAC latency to action.latency=1
#                   - Using predefined leak power value self.leak_power=0
#                   - Calculating energy for FP4MAC action compute.
#                   - Setting FP4MAC energy to action.energy=0.2
#                   - Calculating latency for FP4MAC action compute.
#                   - Setting FP4MAC latency to action.latency=1
#                   - Using predefined leak power value self.leak_power=0
#                 actions:
#                   - name: compute
#                     energy: 0.2
#                     energy_scale: 1
#                     latency: 1
#                     latency_scale: 1
#                     extra_attributes_for_component_model: {}
#                 enabled: true
#                 area: 6e-11
#                 total_area: null
#                 area_scale: 1
#                 leak_power: 0
#                 total_leak_power: 0
#                 leak_power_scale: 1
#                 energy_scale: 1
#                 total_latency: sum(*action2latency.values())
#                 latency_scale: 1
#                 n_parallel_instances: 1
#                 extra_attributes_for_component_model: {}
#                 compute_optimization: []

# %% [markdown]
# ## Next steps for milestone completion
#
# 1. Run all three workloads: **Baseline (FP16)**, **NVFP4 weight-only (W4A16)**, **NVFP4 full (W4A4)**
# 2. Run `evaluate_mapping()` for each and compare energy/latency
# 3. Add your quantization compound component and re-evaluate energy/latency
# 4. Compare the three configurations and report overhead tradeoffs

# %% [markdown]
# ## Milestone Presentation Visualizations
#
# These plots summarize baseline vs NVFP4-weight-only vs NVFP4-full (W4A4) results for presentation.
#
# - Main chart: normalized energy and latency ($\text{quantized} / \text{baseline}$)
# - Optional chart: absolute values (if extractable from mapping objects)
# - A compact summary table is also printed

# %%
import matplotlib.pyplot as plt
import pandas as pd


def _maybe_get(obj, names):
    for n in names:
        if hasattr(obj, n):
            v = getattr(obj, n)
            if callable(v):
                try:
                    return v()
                except Exception:
                    pass
            else:
                return v
    return None


def extract_metrics(mapping_obj):
    """Best-effort extractor for AccelForge mapping result metrics.
    Returns dict with keys: energy_pj, latency_cycles.
    """
    out = {"energy_pj": None, "latency_cycles": None}
    if mapping_obj is None:
        return out

    # Direct/common fields
    out["energy_pj"] = _maybe_get(mapping_obj, [
        "energy_pj", "energy", "total_energy", "total_energy_pj"
    ])
    out["latency_cycles"] = _maybe_get(mapping_obj, [
        "latency_cycles", "latency", "cycles", "total_latency", "total_cycles"
    ])

    # Some objects expose dataframe-like containers
    for container_name in ["df", "dataframe", "mappings_df", "table"]:
        container = _maybe_get(mapping_obj, [container_name])
        if container is None:
            continue
        try:
            cols = [c.lower() for c in container.columns]
            if out["energy_pj"] is None:
                for c in ["energy_pj", "energy", "total_energy", "total_energy_pj"]:
                    if c in cols:
                        out["energy_pj"] = float(container.loc[:, container.columns[cols.index(c)]].min())
                        break
            if out["latency_cycles"] is None:
                for c in ["latency_cycles", "latency", "cycles", "total_latency", "total_cycles"]:
                    if c in cols:
                        out["latency_cycles"] = float(container.loc[:, container.columns[cols.index(c)]].min())
                        break
        except Exception:
            pass

    # Cast if possible
    for k in ["energy_pj", "latency_cycles"]:
        try:
            if out[k] is not None:
                out[k] = float(out[k])
        except Exception:
            out[k] = None

    return out


# Collect current run results (expects earlier cells to have run)
b = globals().get("baseline_result", None)
q = globals().get("quant_result", None)
nv = globals().get("nvfp4_full_result", None)

baseline_metrics = extract_metrics(b)
quant_metrics = extract_metrics(q)
nvfp4_full_metrics = extract_metrics(nv)

rows = [
    {
        "config": "baseline (FP16)",
        "energy_pj": baseline_metrics["energy_pj"],
        "latency_cycles": baseline_metrics["latency_cycles"],
    },
    {
        "config": "NVFP4 weight-only (W4A16)",
        "energy_pj": quant_metrics["energy_pj"],
        "latency_cycles": quant_metrics["latency_cycles"],
    },
    {
        "config": "NVFP4 full (W4A4)",
        "energy_pj": nvfp4_full_metrics["energy_pj"],
        "latency_cycles": nvfp4_full_metrics["latency_cycles"],
    },
]
summary_df = pd.DataFrame(rows)
display(summary_df)

# Normalized chart if all values are available
all_have_metrics = all(
    m["energy_pj"] is not None and m["latency_cycles"] is not None
    for m in [baseline_metrics, quant_metrics, nvfp4_full_metrics]
)

if all_have_metrics:
    configs = ["W4A16\n(weight-only)", "W4A4\n(NVFP4 full)"]
    norm_energy = [
        quant_metrics["energy_pj"] / baseline_metrics["energy_pj"],
        nvfp4_full_metrics["energy_pj"] / baseline_metrics["energy_pj"],
    ]
    norm_latency = [
        quant_metrics["latency_cycles"] / baseline_metrics["latency_cycles"],
        nvfp4_full_metrics["latency_cycles"] / baseline_metrics["latency_cycles"],
    ]

    import numpy as np
    x = np.arange(len(configs))
    width = 0.35

    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    # Normalized bar chart
    ax = axes[0]
    bars1 = ax.bar(x - width/2, norm_energy, width, label="Energy", color="#4C78A8")
    bars2 = ax.bar(x + width/2, norm_latency, width, label="Latency", color="#F58518")
    ax.axhline(1.0, linestyle="--", color="gray", linewidth=1, label="Baseline")
    ax.set_xticks(x)
    ax.set_xticklabels(configs)
    ax.set_ylabel("Normalized (Quantized / Baseline)")
    ax.set_title("Normalized Energy & Latency vs FP16 Baseline")
    ax.legend()
    for bar_group in [bars1, bars2]:
        for bar in bar_group:
            ax.text(bar.get_x() + bar.get_width()/2, bar.get_height(),
                    f"{bar.get_height():.3f}x", ha="center", va="bottom", fontsize=9)

    # Absolute energy comparison
    ax2 = axes[1]
    abs_labels = ["Baseline\n(FP16)", "W4A16", "W4A4"]
    abs_energy = [baseline_metrics["energy_pj"], quant_metrics["energy_pj"], nvfp4_full_metrics["energy_pj"]]
    colors = ["#72B7B2", "#E45756", "#9D755D"]
    bars = ax2.bar(abs_labels, abs_energy, color=colors)
    ax2.set_title("Absolute Energy (pJ)")
    ax2.set_ylabel("pJ")
    for bar in bars:
        ax2.text(bar.get_x() + bar.get_width()/2, bar.get_height(),
                f"{bar.get_height():.0f}", ha="center", va="bottom", fontsize=9)

    plt.tight_layout()
    plt.show()
else:
    print("Metrics are not fully extractable from current result objects.")
    print("Presentation fallback: use parse/evaluate success + printed YAMLs + screenshot of mapping success logs.")
    print("If needed, share the exact result object API and I can wire precise metric extraction.")
# Out:
#                       config  energy_pj  latency_cycles
# 0            baseline (FP16)  6739968.0        524288.0
# 1  NVFP4 weight-only (W4A16)        NaN             NaN
# 2          NVFP4 full (W4A4)  1766284.8         22656.0
# Metrics are not fully extractable from current result objects.
# Presentation fallback: use parse/evaluate success + printed YAMLs + screenshot of mapping success logs.
# If needed, share the exact result object API and I can wire precise metric extraction.
