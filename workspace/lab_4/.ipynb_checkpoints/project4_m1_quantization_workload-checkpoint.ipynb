# %% [markdown]
# # Project 4 — Inference-Faithful Milestone 2 Sweep
#
# This notebook models deployment-time inference more faithfully:
# - weights are prequantized offline,
# - only activation quantization remains online for `w4a4_nvfp4_inference`,
# - and we compare the real quantized workload against an ideal no-overhead quantized lower bound.
#
# Artifacts are written under `project4_m1/sweeps/<shape>/<config>/...` plus sweep-level summary files.

# %%
from pathlib import Path

import pandas as pd

from project4_m1_sweep import (
    AF_AVAILABLE,
    ARCH_PARAMS,
    CONFIGS,
    OUT_DIR,
    ROOT,
    SHAPES,
    SWEEP_DIR,
    load_breakdown_records,
    make_architecture,
    make_workload,
    plot_breakdowns,
    plot_summary,
    run_case,
    run_sweep,
    sanity_check_workloads,
)

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 160)

print(f"Working directory: {Path.cwd()}")
print(f"Lab root: {ROOT}")
print(f"Output directory: {OUT_DIR}")
print(f"Sweep directory: {SWEEP_DIR}")
print(f"AccelForge available: {AF_AVAILABLE}")
print(f"Architecture params: {ARCH_PARAMS}")
# Out:
# Working directory: /home/workspace/workspace/lab_4
# Lab root: /home/workspace/workspace/lab_4
# Output directory: /home/workspace/workspace/lab_4/project4_m1
# Sweep directory: /home/workspace/workspace/lab_4/project4_m1/sweeps
# AccelForge available: True
# Architecture params: {'GLB_SIZE': 524288, 'RF_SIZE': 1024, 'PE_X': 8, 'PE_Y': 8, 'DRAM_BW': 8, 'GLB_BW': 32}

# %% [markdown]
# ## Stable Helper Interface
#
# The sweep is driven through these helpers:
# - `make_workload(shape_name, m, n, k, config_name)`
# - `make_architecture(rescale_energy_pj=3.7, rescale_latency=2)`
# - `run_case(shape_name, dims, config_name)`
# - `run_sweep(shapes, configs)`
# - `plot_summary(results_df)`
# - `plot_breakdowns(breakdown_records)`

# %%
sanity = sanity_check_workloads()
print("Sanity checks passed.")
print("Inference einsums:", sanity["inference_einsums"])
print("Ideal einsums:", sanity["ideal_einsums"])
display(pd.DataFrame.from_dict(SHAPES, orient="index"))
display(pd.DataFrame({"config": CONFIGS}))
# Out:
# Sanity checks passed.
# Inference einsums: ['TensorScaleA', 'TensorQuantA', 'BlockScaleA', 'BlockQuantA', 'MatMulNVFP4', 'RescaleBlockA', 'RescaleBlockW', 'RescaleTensorA', 'RescaleTensorW']
# Ideal einsums: ['MatMulNVFP4']
#                 m      n      k
# decode_up       1  11008   4096
# decode_down     1   4096  11008
# prefill_up    128  11008   4096
# prefill_down  128   4096  11008
#                    config
# 0           fp16_baseline
# 1          w4a16_prequant
# 2    w4a4_nvfp4_inference
# 3  w4a4_ideal_no_overhead

# %% [markdown]
# ## Run The 16-Case Sweep
#
# This executes all 4 shapes × 4 configs, writes per-case workload / arch / mapping artifacts, and emits:
# - `project4_m1/sweeps/results_summary.csv`
# - `project4_m1/sweeps/results_breakdowns.json`

# %%
results_df = run_sweep(SHAPES, CONFIGS)
print(f"Wrote summary CSV: {SWEEP_DIR / 'results_summary.csv'}")
print(f"Wrote breakdown JSON: {SWEEP_DIR / 'results_breakdowns.json'}")
display(results_df)
# Out:
# Getting energy, latency, and leak power for components running MatMul: 100%|██████████| 1/1 [00:00<00:00, 14.33it/s]
# Generating jobs:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating pmapping templates for compute QuantMAC Einsum MatMul: 0it [00:00, ?it/s]
#
# Generating pmapping templates for compute FP4MAC Einsum MatMul: 0it [00:00, ?it/s]
#
# Generating pmapping templates for compute RescaleMAC Einsum MatMul: 0it [00:00, ?it/s]
#
# Generating pmapping templates for compute FP16MAC Einsum MatMul: 0it [00:00, ?it/s]
# Generating pmapping templates for compute FP16MAC Einsum MatMul: 28it [00:00, 211.98it/s]
# Generating pmapping templates for compute FP16MAC Einsum MatMul: 59it [00:00, 258.88it/s]
# Generating pmapping templates for compute FP16MAC Einsum MatMul: 92it [00:00, 287.58it/s]
# Generating pmapping templates for compute FP16MAC Einsum MatMul: 125it [00:00, 301.39it/s]
# Generating pmapping templates for compute FP16MAC Einsum MatMul: 157it [00:00, 305.98it/s]
# Generating pmapping templates for compute FP16MAC Einsum MatMul: 188it [00:00, 250.63it/s]
# Generating pmapping templates for compute FP16MAC Einsum MatMul: 220it [00:00, 269.65it/s]
# Generating pmapping templates for compute FP16MAC Einsum MatMul: 256it [00:00, 276.86it/s]
# Generating jobs: 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
# Einsum MatMul has 256 pmapping templates:
# 	0	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  FP16MAC computes MatMul
# 	1	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	2	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  FP16MAC computes MatMul
# 	3	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	4	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	5	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	6	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	7	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	8	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	9	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	10	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	11	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	12	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	13	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	14	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	15	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	16	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  FP16MAC computes MatMul
# 	17	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	18	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  FP16MAC computes MatMul
# 	19	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	20	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	21	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	22	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	23	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	24	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	25	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	26	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	27	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	28	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	29	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	30	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	31	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	32	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  FP16MAC computes MatMul
# 	33	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	34	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  FP16MAC computes MatMul
# 	35	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	36	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	37	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	38	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	39	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	40	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	41	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	42	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	43	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	44	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	45	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	46	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	47	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	48	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  FP16MAC computes MatMul
# 	49	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	50	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  FP16MAC computes MatMul
# 	51	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	52	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	53	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	54	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	55	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	56	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	57	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	58	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	59	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	60	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	61	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	62	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	63	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	64	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  FP16MAC computes MatMul
# 	65	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  FP16MAC computes MatMul
# 	66	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	67	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	68	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  FP16MAC computes MatMul
# 	69	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  FP16MAC computes MatMul
# 	70	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	71	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	72	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	73	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	74	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	75	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	76	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	77	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	78	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	79	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	80	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	81	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	82	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	83	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	84	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	85	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	86	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	87	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	88	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	89	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	90	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	91	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	92	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	93	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	94	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	95	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	96	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  FP16MAC computes MatMul
# 	97	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  FP16MAC computes MatMul
# 	98	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	99	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	100	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  FP16MAC computes MatMul
# 	101	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  FP16MAC computes MatMul
# 	102	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	103	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	104	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	105	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	106	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	107	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	108	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	109	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	110	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	111	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	112	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	113	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	114	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	115	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	116	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	117	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	118	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	119	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	120	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	121	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	122	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	123	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	124	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	125	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	126	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	127	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	128	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  FP16MAC computes MatMul
# 	129	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  FP16MAC computes MatMul
# 	130	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	131	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	132	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  FP16MAC computes MatMul
# 	133	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  FP16MAC computes MatMul
# 	134	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	135	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	136	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	137	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	138	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	139	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	140	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	141	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	142	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	143	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	144	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	145	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	146	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	147	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	148	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	149	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	150	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	151	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	152	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	153	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	154	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	155	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  [W in RF] T-m  FP16MAC computes MatMul
# 	156	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	157	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	158	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	159	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	160	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  FP16MAC computes MatMul
# 	161	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  FP16MAC computes MatMul
# 	162	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  FP16MAC computes MatMul
# 	163	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  FP16MAC computes MatMul
# 	164	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  FP16MAC computes MatMul
# 	165	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  FP16MAC computes MatMul
# 	166	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	167	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	168	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	169	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	170	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	171	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	172	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  FP16MAC computes MatMul
# 	173	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  FP16MAC computes MatMul
# 	174	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  FP16MAC computes MatMul
# 	175	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  FP16MAC computes MatMul
# 	176	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  FP16MAC computes MatMul
# 	177	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  FP16MAC computes MatMul
# 	178	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	179	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	180	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	181	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	182	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	183	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	184	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	185	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	186	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	187	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	188	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	189	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	190	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	191	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	192	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	193	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [A in GLB] T-ni  T-no  [W in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	194	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  [A in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [W in RF] T-m  FP16MAC computes MatMul
# 	195	[Y in DRAM] [W in DRAM] [A in DRAM] T-m  T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  [A in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [W in RF] T-m  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	196	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  [Y in GLB] T-ki  T-ko  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# 	197	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [W in GLB] T-m  [Y in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [Y in RF] T-ki  T-ko  [A in RF] T-ni  T-no  FP16MAC computes MatMul
# 	198	[Y in DRAM] [W in DRAM] [A in DRAM] T-ki  T-ko  T-m  [A in GLB] T-ni  T-no  [Y in GLB] T-ki  T-ko  [W in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ko  S-Y-ki  S-X-no  S-X-ni  S-X-m  S-X-ko  S-X-ki  [A in RF] T-ni  T-no  [Y in RF] T-ki  T-ko  FP16MAC computes MatMul
# ...
# 	249	[Yraw in DRAM] [Wq in DRAM] [Aq in DRAM] T-kbi  T-kbo  T-m  T-ni  T-no  [Yraw in GLB] T-ki  [Aq in GLB] T-ni  T-no  [Wq in GLB] T-m  S-Y-no  S-Y-ni  S-Y-m  S-Y-ki  S-Y-kbo  S-Y-kbi  S-X-no  S-X-ni  S-X-m  S-X-ki  S-X-kbo  S-X-kbi  [Yraw in RF] T-ki  [Wq in RF] T-m  [Aq in RF] T-ni  T-no  FP4MAC computes MatMulNVFP4
# 	250	[Yraw in DRAM] [Wq in DRAM] [Aq in DRAM] T-kbi  T-kbo  T-m  T-ni  T-no  [Yraw in GLB] T-ki  [Wq in GLB] T-m  [Aq in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ki  S-Y-kbo  S-Y-kbi  S-X-no  S-X-ni  S-X-m  S-X-ki  S-X-kbo  S-X-kbi  [Aq in RF] T-ni  T-no  [Wq in RF] T-m  [Yraw in RF] T-ki  FP4MAC computes MatMulNVFP4
# 	251	[Yraw in DRAM] [Wq in DRAM] [Aq in DRAM] T-kbi  T-kbo  T-m  T-ni  T-no  [Yraw in GLB] T-ki  [Wq in GLB] T-m  [Aq in GLB] S-Y-no  S-Y-ni  S-Y-m  S-Y-ki  S-Y-kbo  S-Y-kbi  S-X-no  S-X-ni  S-X-m  S-X-ki  S-X-kbo  S-X-kbi  [Aq in RF] T-ni  T-no  [Yraw in RF] T-ki  [Wq in RF] T-m  FP4MAC computes MatMulNVFP4
# 	252	[Yraw in DRAM] [Wq in DRAM] [Aq in DRAM] T-kbi  T-kbo  T-m  T-ni  T-no  [Yraw in GLB] T-ki  [Wq in GLB] T-m  [Aq in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ki  S-Y-kbo  S-Y-kbi  S-X-no  S-X-ni  S-X-m  S-X-ki  S-X-kbo  S-X-kbi  [Wq in RF] T-m  [Aq in RF] T-ni  T-no  [Yraw in RF] T-ki  FP4MAC computes MatMulNVFP4
# 	253	[Yraw in DRAM] [Wq in DRAM] [Aq in DRAM] T-kbi  T-kbo  T-m  T-ni  T-no  [Yraw in GLB] T-ki  [Wq in GLB] T-m  [Aq in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ki  S-Y-kbo  S-Y-kbi  S-X-no  S-X-ni  S-X-m  S-X-ki  S-X-kbo  S-X-kbi  [Wq in RF] T-m  [Yraw in RF] T-ki  [Aq in RF] T-ni  T-no  FP4MAC computes MatMulNVFP4
# 	254	[Yraw in DRAM] [Wq in DRAM] [Aq in DRAM] T-kbi  T-kbo  T-m  T-ni  T-no  [Yraw in GLB] T-ki  [Wq in GLB] T-m  [Aq in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ki  S-Y-kbo  S-Y-kbi  S-X-no  S-X-ni  S-X-m  S-X-ki  S-X-kbo  S-X-kbi  [Yraw in RF] T-ki  [Aq in RF] T-ni  T-no  [Wq in RF] T-m  FP4MAC computes MatMulNVFP4
# 	255	[Yraw in DRAM] [Wq in DRAM] [Aq in DRAM] T-kbi  T-kbo  T-m  T-ni  T-no  [Yraw in GLB] T-ki  [Wq in GLB] T-m  [Aq in GLB] T-ni  T-no  S-Y-no  S-Y-ni  S-Y-m  S-Y-ki  S-Y-kbo  S-Y-kbi  S-X-no  S-X-ni  S-X-m  S-X-ki  S-X-kbo  S-X-kbi  [Yraw in RF] T-ki  [Wq in RF] T-m  [Aq in RF] T-ni  T-no  FP4MAC computes MatMulNVFP4
# Not tracking memory DRAM. It is big enough to simultaneously hold every workload tensor that may be stored in it. Max possible usage: 11.73%
# Not tracking memory GLB across joining stages. It is never reserved across fused loop iterations.
# Not tracking memory RF across joining stages. It is never reserved across fused loop iterations.
# Insufficient jobs available to utilize available threads. Splitting jobs into smaller chunks.
# Generating pmappings: 100%|██████████| 256/256 [00:35<00:00,  7.25it/s]
# Grouping pmappings for MatMulNVFP4: 100%|██████████| 1/1 [00:00<00:00,  1.65it/s]
# MatMulNVFP4: 7.61e11 total, 1 (1/7.61e11) valid, 3.19e07 (1/2.39e04) evaluated, 2 (1/3.81e11) Pareto-Optimal
# Total: 7.61e11 total, 1 (1/7.61e11) valid, 3.19e07 (1/2.39e04) evaluated, 2 (1/3.81e11) Pareto-Optimal
# Compressing pmappings: 100%|██████████| 1/1 [00:00<00:00, 274.41it/s]
# Final consolidate: 100%|██████████| 1/1 [00:00<00:00, 15033.35it/s]
# Evaluating chosen mappings in detail: 100%|██████████| 2/2 [00:00<00:00, 23.93it/s]
# Wrote summary CSV: /home/workspace/workspace/lab_4/project4_m1/sweeps/results_summary.csv
# Wrote breakdown JSON: /home/workspace/workspace/lab_4/project4_m1/sweeps/results_breakdowns.json
#            shape                  config    m      n      k   kb  ki               status                                          arch_file  \
# 0      decode_up           fp16_baseline    1  11008   4096  256  16  mapped_metrics_only  /home/workspace/workspace/lab_4/project4_m1/sw...
# 1      decode_up          w4a16_prequant    1  11008   4096  256  16  mapped_metrics_only  /home/workspace/workspace/lab_4/project4_m1/sw...
# 2      decode_up    w4a4_nvfp4_inference    1  11008   4096  256  16               mapped  /home/workspace/workspace/lab_4/project4_m1/sw...
# 3      decode_up  w4a4_ideal_no_overhead    1  11008   4096  256  16               mapped  /home/workspace/workspace/lab_4/project4_m1/sw...
# 4    decode_down           fp16_baseline    1   4096  11008  688  16  mapped_metrics_only  /home/workspace/workspace/lab_4/project4_m1/sw...
# 5    decode_down          w4a16_prequant    1   4096  11008  688  16  mapped_metrics_only  /home/workspace/workspace/lab_4/project4_m1/sw...
# 6    decode_down    w4a4_nvfp4_inference    1   4096  11008  688  16               mapped  /home/workspace/workspace/lab_4/project4_m1/sw...
# 7    decode_down  w4a4_ideal_no_overhead    1   4096  11008  688  16               mapped  /home/workspace/workspace/lab_4/project4_m1/sw...
# 8     prefill_up           fp16_baseline  128  11008   4096  256  16  mapped_metrics_only  /home/workspace/workspace/lab_4/project4_m1/sw...
# 9     prefill_up          w4a16_prequant  128  11008   4096  256  16  mapped_metrics_only  /home/workspace/workspace/lab_4/project4_m1/sw...
# 10    prefill_up    w4a4_nvfp4_inference  128  11008   4096  256  16  mapped_metrics_only  /home/workspace/workspace/lab_4/project4_m1/sw...
# 11    prefill_up  w4a4_ideal_no_overhead  128  11008   4096  256  16  mapped_metrics_only  /home/workspace/workspace/lab_4/project4_m1/sw...
# 12  prefill_down           fp16_baseline  128   4096  11008  688  16  mapped_metrics_only  /home/workspace/workspace/lab_4/project4_m1/sw...
# 13  prefill_down          w4a16_prequant  128   4096  11008  688  16  mapped_metrics_only  /home/workspace/workspace/lab_4/project4_m1/sw...
# 14  prefill_down    w4a4_nvfp4_inference  128   4096  11008  688  16  mapped_metrics_only  /home/workspace/workspace/lab_4/project4_m1/sw...
# 15  prefill_down  w4a4_ideal_no_overhead  128   4096  11008  688  16  mapped_metrics_only  /home/workspace/workspace/lab_4/project4_m1/sw...
#
#                                         workload_file                                       mapping_file                                     breakdown_file  \
# 0   /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...
# 1   /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...
# 2   /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...
# 3   /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...
# 4   /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...
# 5   /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...
# 6   /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...
# 7   /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...
# 8   /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...
# 9   /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...
# 10  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...
# 11  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...
# 12  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...
# 13  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...
# 14  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...
# 15  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...  /home/workspace/workspace/lab_4/project4_m1/sw...
#
#     mapping_exported                               mapping_export_error     energy_pj  latency_cycles dominant_energy_einsum  dominant_energy_pj  \
# 0              False  PydanticSerializationError: Error calling func...  1.838624e+08    1.127219e+07                 MatMul        1.838624e+08
# 1              False  PydanticSerializationError: Error calling func...  3.768987e+08    1.409024e+07               DequantW        1.930363e+08
# 2               True                                                NaN  1.644983e+08    6.627586e+06            MatMulNVFP4        5.833359e+07
# 3               True                                                NaN  5.833359e+07    7.045120e+05            MatMulNVFP4        5.833359e+07
# 4              False  PydanticSerializationError: Error calling func...  1.839004e+08    1.127219e+07                 MatMul        1.839004e+08
# 5              False  PydanticSerializationError: Error calling func...  3.769367e+08    1.409024e+07               DequantW        1.930363e+08
# 6               True                                                NaN  1.658629e+08    6.615058e+06            MatMulNVFP4        5.833359e+07
# 7               True                                                NaN  5.833359e+07    7.045120e+05            MatMulNVFP4        5.833359e+07
# 8              False  PydanticSerializationError: Error calling func...  1.406575e+10    1.442841e+09                 MatMul        1.406575e+10
# 9              False  PydanticSerializationError: Error calling func...  1.425878e+10    1.445659e+09                MatMulQ        1.406575e+10
# 10             False  PydanticSerializationError: Error calling func...  1.771971e+10    4.285915e+08          RescaleBlockA        4.948774e+09
# 11             False  PydanticSerializationError: Error calling func...  4.581412e+09    3.607101e+08            MatMulNVFP4        4.581412e+09
# 12             False  PydanticSerializationError: Error calling func...  1.407061e+10    1.442841e+09                 MatMul        1.407061e+10
# 13             False  PydanticSerializationError: Error calling func...  1.426365e+10    1.445659e+09                MatMulQ        1.407061e+10
# 14             False  PydanticSerializationError: Error calling func...  1.789944e+10    4.176049e+08          RescaleBlockA        4.948774e+09
# 15             False  PydanticSerializationError: Error calling func...  4.582076e+09    3.607101e+08            MatMulNVFP4        4.582076e+09
#
#    dominant_latency_einsum  dominant_latency_cycles  baseline_energy_pj  baseline_latency_cycles  energy_norm_vs_fp16  latency_norm_vs_fp16  ideal_energy_pj  \
# 0                   MatMul             1.127219e+07        1.838624e+08             1.127219e+07             1.000000              1.000000     5.833359e+07
# 1                  MatMulQ             1.127219e+07        1.838624e+08             1.127219e+07             2.049895              1.250000     5.833359e+07
# 2            RescaleBlockW             5.636096e+06        1.838624e+08             1.127219e+07             0.894681              0.587959     5.833359e+07
# 3              MatMulNVFP4             7.045120e+05        1.838624e+08             1.127219e+07             0.317268              0.062500     5.833359e+07
# 4                   MatMul             1.127219e+07        1.839004e+08             1.127219e+07             1.000000              1.000000     5.833359e+07
# 5                  MatMulQ             1.127219e+07        1.839004e+08             1.127219e+07             2.049678              1.250000     5.833359e+07
# 6            RescaleBlockW             5.636096e+06        1.839004e+08             1.127219e+07             0.901917              0.586848     5.833359e+07
# 7              MatMulNVFP4             7.045120e+05        1.839004e+08             1.127219e+07             0.317202              0.062500     5.833359e+07
# 8                   MatMul             1.442841e+09        1.406575e+10             1.442841e+09             1.000000              1.000000     4.581412e+09
# 9                  MatMulQ             1.442841e+09        1.406575e+10             1.442841e+09             1.013724              1.001953     4.581412e+09
# 10             MatMulNVFP4             3.607101e+08        1.406575e+10             1.442841e+09             1.259777              0.297047     4.581412e+09
# 11             MatMulNVFP4             3.607101e+08        1.406575e+10             1.442841e+09             0.325714              0.250000     4.581412e+09
# 12                  MatMul             1.442841e+09        1.407061e+10             1.442841e+09             1.000000              1.000000     4.582076e+09
# 13                 MatMulQ             1.442841e+09        1.407061e+10             1.442841e+09             1.013719              1.001953     4.582076e+09
# 14             MatMulNVFP4             3.607101e+08        1.407061e+10             1.442841e+09             1.272115              0.289432     4.582076e+09
# 15             MatMulNVFP4             3.607101e+08        1.407061e+10             1.442841e+09             0.325649              0.250000     4.582076e+09
#
#     ideal_latency_cycles  energy_norm_vs_ideal  latency_norm_vs_ideal  energy_over_ideal_pj  latency_over_ideal_cycles
# 0               704512.0              3.151913              16.000000          1.255288e+08               1.056768e+07
# 1               704512.0              6.461092              20.000000          3.185651e+08               1.338573e+07
# 2               704512.0              2.819958               9.407343          1.061647e+08               5.923074e+06
# 3               704512.0              1.000000               1.000000          0.000000e+00               0.000000e+00
# 4               704512.0              3.152564              16.000000          1.255668e+08               1.056768e+07
# 5               704512.0              6.461743              20.000000          3.186031e+08               1.338573e+07
# 6               704512.0              2.843351               9.389560          1.075293e+08               5.910546e+06
# 7               704512.0              1.000000               1.000000          0.000000e+00               0.000000e+00
# 8            360710144.0              3.070177               4.000000          9.484334e+09               1.082130e+09
# 9            360710144.0              3.112312               4.007812          9.677370e+09               1.084948e+09
# 10           360710144.0              3.867740               1.188188          1.313830e+10               6.788131e+07
# 11           360710144.0              1.000000               1.000000          0.000000e+00               0.000000e+00
# 12           360710144.0              3.070794               4.000000          9.488536e+09               1.082130e+09
# 13           360710144.0              3.112923               4.007812          9.681573e+09               1.084948e+09
# 14           360710144.0              3.906404               1.157730          1.331737e+10               5.689474e+07
# 15           360710144.0              1.000000               1.000000          0.000000e+00               0.000000e+00

# %% [markdown]
# ## Tables For Proposal Use
#
# These are the three main summary views:
# - absolute energy and latency,
# - normalized energy and latency versus FP16 baseline,
# - and the gap between the real W4A4 inference workload and the ideal no-overhead quantized lower bound.

# %%
absolute_table = results_df[[
    "shape",
    "config",
    "energy_pj",
    "latency_cycles",
    "dominant_energy_einsum",
    "dominant_latency_einsum",
    "status",
]].sort_values(["shape", "config"])

normalized_table = results_df[[
    "shape",
    "config",
    "energy_norm_vs_fp16",
    "latency_norm_vs_fp16",
    "energy_norm_vs_ideal",
    "latency_norm_vs_ideal",
]].sort_values(["shape", "config"])

overhead_gap_table = results_df.loc[
    results_df["config"] == "w4a4_nvfp4_inference",
    [
        "shape",
        "energy_pj",
        "ideal_energy_pj",
        "energy_over_ideal_pj",
        "latency_cycles",
        "ideal_latency_cycles",
        "latency_over_ideal_cycles",
        "dominant_energy_einsum",
        "dominant_latency_einsum",
    ],
].sort_values("shape")

display(absolute_table)
display(normalized_table)
display(overhead_gap_table)
# Out:
#            shape                  config     energy_pj  latency_cycles dominant_energy_einsum dominant_latency_einsum               status
# 4    decode_down           fp16_baseline  1.839004e+08    1.127219e+07                 MatMul                  MatMul  mapped_metrics_only
# 5    decode_down          w4a16_prequant  3.769367e+08    1.409024e+07               DequantW                 MatMulQ  mapped_metrics_only
# 7    decode_down  w4a4_ideal_no_overhead  5.833359e+07    7.045120e+05            MatMulNVFP4             MatMulNVFP4               mapped
# 6    decode_down    w4a4_nvfp4_inference  1.658629e+08    6.615058e+06            MatMulNVFP4           RescaleBlockW               mapped
# 0      decode_up           fp16_baseline  1.838624e+08    1.127219e+07                 MatMul                  MatMul  mapped_metrics_only
# 1      decode_up          w4a16_prequant  3.768987e+08    1.409024e+07               DequantW                 MatMulQ  mapped_metrics_only
# 3      decode_up  w4a4_ideal_no_overhead  5.833359e+07    7.045120e+05            MatMulNVFP4             MatMulNVFP4               mapped
# 2      decode_up    w4a4_nvfp4_inference  1.644983e+08    6.627586e+06            MatMulNVFP4           RescaleBlockW               mapped
# 12  prefill_down           fp16_baseline  1.407061e+10    1.442841e+09                 MatMul                  MatMul  mapped_metrics_only
# 13  prefill_down          w4a16_prequant  1.426365e+10    1.445659e+09                MatMulQ                 MatMulQ  mapped_metrics_only
# 15  prefill_down  w4a4_ideal_no_overhead  4.582076e+09    3.607101e+08            MatMulNVFP4             MatMulNVFP4  mapped_metrics_only
# 14  prefill_down    w4a4_nvfp4_inference  1.789944e+10    4.176049e+08          RescaleBlockA             MatMulNVFP4  mapped_metrics_only
# 8     prefill_up           fp16_baseline  1.406575e+10    1.442841e+09                 MatMul                  MatMul  mapped_metrics_only
# 9     prefill_up          w4a16_prequant  1.425878e+10    1.445659e+09                MatMulQ                 MatMulQ  mapped_metrics_only
# 11    prefill_up  w4a4_ideal_no_overhead  4.581412e+09    3.607101e+08            MatMulNVFP4             MatMulNVFP4  mapped_metrics_only
# 10    prefill_up    w4a4_nvfp4_inference  1.771971e+10    4.285915e+08          RescaleBlockA             MatMulNVFP4  mapped_metrics_only
#            shape                  config  energy_norm_vs_fp16  latency_norm_vs_fp16  energy_norm_vs_ideal  latency_norm_vs_ideal
# 4    decode_down           fp16_baseline             1.000000              1.000000              3.152564              16.000000
# 5    decode_down          w4a16_prequant             2.049678              1.250000              6.461743              20.000000
# 7    decode_down  w4a4_ideal_no_overhead             0.317202              0.062500              1.000000               1.000000
# 6    decode_down    w4a4_nvfp4_inference             0.901917              0.586848              2.843351               9.389560
# 0      decode_up           fp16_baseline             1.000000              1.000000              3.151913              16.000000
# 1      decode_up          w4a16_prequant             2.049895              1.250000              6.461092              20.000000
# 3      decode_up  w4a4_ideal_no_overhead             0.317268              0.062500              1.000000               1.000000
# 2      decode_up    w4a4_nvfp4_inference             0.894681              0.587959              2.819958               9.407343
# 12  prefill_down           fp16_baseline             1.000000              1.000000              3.070794               4.000000
# 13  prefill_down          w4a16_prequant             1.013719              1.001953              3.112923               4.007812
# 15  prefill_down  w4a4_ideal_no_overhead             0.325649              0.250000              1.000000               1.000000
# 14  prefill_down    w4a4_nvfp4_inference             1.272115              0.289432              3.906404               1.157730
# 8     prefill_up           fp16_baseline             1.000000              1.000000              3.070177               4.000000
# 9     prefill_up          w4a16_prequant             1.013724              1.001953              3.112312               4.007812
# 11    prefill_up  w4a4_ideal_no_overhead             0.325714              0.250000              1.000000               1.000000
# 10    prefill_up    w4a4_nvfp4_inference             1.259777              0.297047              3.867740               1.188188
#            shape     energy_pj  ideal_energy_pj  energy_over_ideal_pj  latency_cycles  ideal_latency_cycles  latency_over_ideal_cycles dominant_energy_einsum  \
# 6    decode_down  1.658629e+08     5.833359e+07          1.075293e+08       6615058.0              704512.0                  5910546.0            MatMulNVFP4
# 2      decode_up  1.644983e+08     5.833359e+07          1.061647e+08       6627586.0              704512.0                  5923074.0            MatMulNVFP4
# 14  prefill_down  1.789944e+10     4.582076e+09          1.331737e+10     417604880.0           360710144.0                 56894736.0          RescaleBlockA
# 10    prefill_up  1.771971e+10     4.581412e+09          1.313830e+10     428591456.0           360710144.0                 67881312.0          RescaleBlockA
#
#    dominant_latency_einsum
# 6            RescaleBlockW
# 2            RescaleBlockW
# 14             MatMulNVFP4
# 10             MatMulNVFP4

# %% [markdown]
# ## Plots
#
# `plot_summary(results_df)` renders:
# 1. grouped bars for normalized energy and latency,
# 2. a stacked W4A4 inference energy breakdown by shape,
# 3. and the overhead-to-ideal chart.
#
# `plot_breakdowns(breakdown_records)` renders a per-einsum stacked breakdown for the inference workload.

# %%
figures = plot_summary(results_df)
breakdown_records = load_breakdown_records()
breakdown_fig = plot_breakdowns(breakdown_records)
print("Generated figure keys:", list(figures.keys()))
# Out:
# Generated figure keys: ['normalized_summary', 'inference_breakdown', 'overhead_vs_ideal']

# %% [markdown]
# ## Post-Run Checks
#
# These assertions encode the milestone sanity checks directly in the notebook.

# %%
assert len(results_df) == 16, f"Expected 16 sweep rows, found {len(results_df)}"
assert (SWEEP_DIR / "results_summary.csv").exists()
assert (SWEEP_DIR / "results_breakdowns.json").exists()

if results_df["latency_cycles"].notna().all():
    merged = results_df.pivot(index="shape", columns="config", values="latency_cycles")
    assert (merged["w4a4_ideal_no_overhead"] <= merged["w4a4_nvfp4_inference"]).all(), "Ideal latency should be <= inference latency"

if results_df["energy_pj"].notna().all():
    larger_k_shapes = [shape for shape, dims in SHAPES.items() if dims["k"] >= 4096]
    larger_k_df = results_df[(results_df["config"] == "w4a4_nvfp4_inference") & (results_df["shape"].isin(larger_k_shapes))]
    assert not larger_k_df.empty
    assert larger_k_df["dominant_energy_einsum"].fillna("").str.startswith("Rescale").any(), "Expected a rescale stage to dominate energy for at least one larger-k inference case"

print("Post-run checks passed.")
# Out:
# Post-run checks passed.
